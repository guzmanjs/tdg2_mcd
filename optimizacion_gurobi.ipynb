# %%
#!pip install gurobipy pandas openpyxl
#!pip install gdown
# Out:
# Collecting gdown
#   Downloading gdown-5.2.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting beautifulsoup4 (from gdown)
#   Downloading beautifulsoup4-4.13.4-py3-none-any.whl.metadata (3.8 kB)
# Collecting filelock (from gdown)
#   Downloading filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting requests[socks] (from gdown)
#   Downloading requests-2.32.4-py3-none-any.whl.metadata (4.9 kB)
# Collecting tqdm (from gdown)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4->gdown)
#   Downloading soupsieve-2.7-py3-none-any.whl.metadata (4.6 kB)
# Collecting typing-extensions>=4.0.0 (from beautifulsoup4->gdown)
#   Downloading typing_extensions-4.14.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting charset_normalizer<4,>=2 (from requests[socks]->gdown)
#   Downloading charset_normalizer-3.4.2-cp313-cp313-win_amd64.whl.metadata (36 kB)
# Collecting idna<4,>=2.5 (from requests[socks]->gdown)
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests[socks]->gdown)
#   Downloading urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests[socks]->gdown)
#   Downloading certifi-2025.6.15-py3-none-any.whl.metadata (2.4 kB)
# Collecting PySocks!=1.5.7,>=1.5.6 (from requests[socks]->gdown)
#   Downloading PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: colorama in c:\users\usuario\appdata\roaming\python\python313\site-packages (from tqdm->gdown) (0.4.6)
# Downloading gdown-5.2.0-py3-none-any.whl (18 kB)
# Downloading beautifulsoup4-4.13.4-py3-none-any.whl (187 kB)
# Downloading soupsieve-2.7-py3-none-any.whl (36 kB)
# Downloading typing_extensions-4.14.0-py3-none-any.whl (43 kB)
# Downloading filelock-3.18.0-py3-none-any.whl (16 kB)
# Downloading requests-2.32.4-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.2-cp313-cp313-win_amd64.whl (105 kB)
# Downloading idna-3.10-py3-none-any.whl (70 kB)
# Downloading urllib3-2.5.0-py3-none-any.whl (129 kB)
# Downloading certifi-2025.6.15-py3-none-any.whl (157 kB)
# Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: urllib3, typing-extensions, tqdm, soupsieve, PySocks, idna, filelock, charset_normalizer, certifi, requests, beautifulsoup4, gdown
#
#    ----------------------------------------  0/12 [urllib3]
#    --- ------------------------------------  1/12 [typing-extensions]
#    ------ ---------------------------------  2/12 [tqdm]
#    ------ ---------------------------------  2/12 [tqdm]
#    ---------- -----------------------------  3/12 [soupsieve]
#    ---------------- -----------------------  5/12 [idna]
#    ----------------------- ----------------  7/12 [charset_normalizer]
#    ------------------------------ ---------  9/12 [requests]
#    --------------------------------- ------ 10/12 [beautifulsoup4]
#    --------------------------------- ------ 10/12 [beautifulsoup4]
#    --------------------------------- ------ 10/12 [beautifulsoup4]
#    --------------------------------- ------ 10/12 [beautifulsoup4]
#    ---------------------------------------- 12/12 [gdown]
#
# Successfully installed PySocks-1.7.1 beautifulsoup4-4.13.4 certifi-2025.6.15 charset_normalizer-3.4.2 filelock-3.18.0 gdown-5.2.0 idna-3.10 requests-2.32.4 soupsieve-2.7 tqdm-4.67.1 typing-extensions-4.14.0 urllib3-2.5.0

# %%
import pandas as pd
import gdown
from gurobipy import Model, GRB, quicksum

# %%
#Descargamos el archivo desde Drive
file_id = '1BNagy0v4Nwg8dCyvZdS9rZOaR2-L9ROL'
output = 'INPUT MODELO OPTIMIZACIÓN.xlsx'
gdown.download(f"https://drive.google.com/uc?id={file_id}", output, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1BNagy0v4Nwg8dCyvZdS9rZOaR2-L9ROL
# To: e:\proyectos\optimizacion_TDG\tdg2_mcd\INPUT MODELO OPTIMIZACIÓN.xlsx
# 100%|██████████| 364k/364k [00:00<00:00, 1.42MB/s]
# 'INPUT MODELO OPTIMIZACIÓN.xlsx'

# %%
# ==== PREPARACIÓN DE DICCIONARIOS PARA CONSTRUIR CONJUNTOS Y PARÁMETROS ===
dias = 12 #Días de corrida del modelo
PENALIZACION = 10000 #Penalización del incumplimiento del mínimo de la desviación

# === 1. LEER DATOS DE ENTRADA ===
archivo = "INPUT MODELO OPTIMIZACIÓN.xlsx"
df_granjas = pd.read_excel(archivo, sheet_name="Input_Granjas")
df_demanda = pd.read_excel(archivo, sheet_name="Input_Demanda", header=4)
df_raw = pd.read_excel(archivo, sheet_name="Input_Demanda", header=None)

# === PARÁMETROS ===
W, ADG, CAT, N, TIPO = {}, {}, {}, {}, {}

for _, row in df_granjas.iterrows():
    g, p, s = row["GRANJA"], row["GALPON"], row["SEXO"]
    N[(g, p, s)] = row["SALDO"]
    TIPO[(g, p, s)] = row["TIPO"]

    for d in range(1, 1 + dias):
        col_w = 'WEIGTH' if d == 1 else f'WEIGTH{d}'
        col_adg = 'ADG' if d == 1 else f'ADG{d}'
        col_cat = 'CAT PESO' if d == 1 else f'CAT PESO{d}'

        if pd.notnull(row[col_w]): W[(g, p, s, d)] = float(row[col_w])
        if pd.notnull(row[col_adg]): ADG[(g, p, s, d)] = float(row[col_adg])
        if pd.notnull(row[col_cat]): CAT[(g, p, s, d)] = row[col_cat].strip().upper()

# === DEMANDA Q[tipo, cat, d] ===
Q = {}
tipos_validos = ["CAMPESINO", "BLANCO"]
cats_validas = ["PEQUEÑO", "MEDIANO", "GRANDE"]

for _, row in df_demanda.iterrows():
    t, c = row["Tipo"], row["Categoria Peso"]
    if t in tipos_validos and c in cats_validas:
        for d in range(1, 1 + dias):
            val = row.get(f"Day{d}")
            if pd.notnull(val):
                Q[(t, c, d)] = val

# === MAPD y TOT ===
MAPD = {}

for i in range(13, 13 + dias):
    semana = df_raw.iloc[i, 1]
    dia = df_raw.iloc[i, 2]
    if pd.notnull(semana) and pd.notnull(dia):
        MAPD[int(dia)] = int(semana)

TOT = {}
for d in range (1, 1 + dias):
    s = MAPD.get(d) #Se trae la semana a la que pertenece cada uno de los días
    val_tot = df_raw.iloc[14 + s, 5] #La demanda de la semana está alacenado de la fila 16 en adelante en la columna 5. Se asegura de que se trae la demanda según la semana
    if pd.notnull(val_tot): TOT[s] = float(val_tot)

tol = float(df_raw.iloc[1, 2])  # Tolerancia

# %%
# === 2. DEFINICIÓN DE CONJUNTOS ===


# Conjunto de grupos: (granja, galpón, sexo)
GP = list(N.keys())

# Conjunto de días en el horizonte (por ejemplo 1 a 6)
D = sorted(set(d for (_, _, _, d) in W.keys()))

# Conjunto de tipos de pollo
T = sorted(set(TIPO.values()))

# Conjunto de categorías de peso
C = sorted(set(c for (_, _, _, _), c in CAT.items()))

# Conjunto de semanas (extraído del mapeo día → semana)
WEEK = sorted(set(MAPD[d] for d in MAPD))

# %%
# === 3. CREACION DEL MODELO ===

# === MODELO VACÍO ===
model = Model("modelo_cosecha_pollos")

# === VARIABLES ===

# x[g, p, s, d] = 1 si el grupo se cosecha el día d
x = model.addVars(GP, D, vtype=GRB.BINARY, name="x")

# dev[t, c, d] = desviación absoluta entre cosecha y demanda para ese tipo, categoría y día
dev = model.addVars(T, C, D, vtype=GRB.CONTINUOUS, lb=0, name="dev")

# === Variable para la restricción suave 
violacion = model.addVars(T, C, D, name="violacion", vtype=GRB.CONTINUOUS, lb=0.0) #Almacena cuantos pollos por fuera de la desviación

# %%
# === 4. PLANTEAMIENTO DE LAS RESTRICCIONES ===

# === R1: Cada grupo se cosecha 1 sola vez

for g, p, s in GP:
    model.addConstr(
        quicksum(x[g, p, s, d] for d in D) <= 1,
        name=f"R1_una_vez_{g}_{p}_{s}"
    )

# %% [markdown]
# # === R2: la diferencia absoluta entre lo cosechado y la demanda debe ser menor a la desviacion ===
#
# #for t in T:
#     #for c in C:
#         #for d in D:
#             #q_val = Q.get((t, c, d), 0)
#             #if q_val > 0:
#                 #model.addConstr(
#                     #dev[t, c, d] <= 0.15 * q_val,
#                     #name=f"R2_limite_10pct_{t}_{c}_{d}"
#                 #)
# #================================================================================================
#
# for t in T:
#     for c in C:
#         for d in D:
#             cantidad_real = quicksum(
#                 N[gps] * x[gps + (d,)] # Asegura que el grupo haya sido cosechado, y agarra la cantidad del grupo (N)
#                 for gps in GP
#                 if TIPO[gps] == t and CAT.get(gps + (d,), None) == c #Asegura que las categorias y tipos coincidan
#             )
#             if (t, c, d) in Q:
#                 model.addConstr(cantidad_real - Q[t, c, d] <= dev[t, c, d], # Modelado de la restricción en absoluto
#                                 name=f"R2_sup_{t}_{c}_{d}")
#                 model.addConstr(Q[t, c, d] - cantidad_real <= dev[t, c, d], # Modelado de la restricción en absoluto
#                                 name=f"R2_inf_{t}_{c}_{d}")

# %% [markdown]
# # === R2.2. Restricción suave que permite que se viole el mix diario de pollos
#
# for t in T:
#     for c in C:
#         for d in D:
#             q_val = Q.get((t, c, d), 0)
#             if q_val > 0:
#                 model.addConstr(
#                     dev[t, c, d] - tol * q_val <= violacion[t, c, d],
#                     name=f"soft_limite_violacion_{t}_{c}_{d}"
#                 )
#             else:
#                 # Si no hay demanda, no permitas desviación
#                 model.addConstr(dev[t, c, d] == 0)

# %%
# === R3: Para los grupos mixtos, se prioriza cosechar las hembras sobre los machos ===
galpones = set((g, p) for g, p, s in GP)

for g, p in galpones:
    if ((g, p, 'HEMBRA') in GP) and ((g, p, 'MACHO') in GP):
        for d in D:
            if d >= 5: #Solo tiene sentido si han transcurrido más de 4 días 
                suma_hembras_previos = quicksum(
                    x[g, p, 'HEMBRA', dp]
                    for dp in range(d - 4, d) if dp in D #Valida si las hembras de un galpon mixto se cosechan durante 4 días anteriores
                )
                model.addConstr(
                    x[g, p, 'MACHO', d] <= 1 - suma_hembras_previos,
                    name=f"R3_prioridad_{g}_{p}_{d}" #Evita que se cosechen los machos si no han pasado 4 días o más desde la cosecha de hembras
                )

# === R4: Asegura que la cosecha de la semana esté dentro del rango de tolerancia de la demanda total para esa semana ===

for w in WEEK:
    dias_semana = [d for d in D if MAPD.get(d) == w]
    
    suma_cosechada = quicksum(
        N[gps] * x[gps + (d,)] #Computa cuantos pollos sales por grupo cosechado
        for gps in GP
        for d in dias_semana
    )
    
    if w in TOT:
        model.addConstr(
            suma_cosechada >= (1 - tol) * TOT[w], #Límite inferior de la demanda total semanal
            name=f"R5_inferior_{w}"
        )
        model.addConstr(
            suma_cosechada <= (1 + tol) * TOT[w], #Límite superior de la demanda total semanal
            name=f"R5_superior_{w}"
        )


# === R5: No cosechar pesos por encima de 3.5 Kg ===
for (g, p, s, d), peso in W.items(): #itera sobre cada arreglo de granja, galpon, sexo y día para asegurar que el peso no se pase de 3.5 Kg
    if peso > 3.5:
        model.addConstr(
            x[g, p, s, d] == 0,
            name=f"R_peso_maximo_{g}_{p}_{s}_{d}"
        )


# === R6: El mínimo peso del pollo campesino debe ser 3 Kg ===

for (g, p, s, d), peso in W.items():
    if TIPO.get((g, p, s)) == "CAMPESINO" and peso < 3.0:
        model.addConstr(
            x[g, p, s, d] == 0,
            name=f"R_peso_min_campesino_{g}_{p}_{s}_{d}"
        )

# === R7: Solo cosechar los grupos con demanda ===

for (g, p, s, d), cat in CAT.items():
    tipo = TIPO.get((g, p, s))
    if (tipo, cat, d) not in Q:
        model.addConstr(
            x[g, p, s, d] == 0,
            name=f"R_sin_demanda_{g}_{p}_{s}_{d}"
        )

# %%
# === R2: Que para los grupos pequeños y medianos se cumpla la cuota diaria 

for t in T:
    for c in ["PEQUEÑO", "MEDIANO"]:  # Solo aplica a estas categorías
        for d in D:
            q_val = Q.get((t, c, d), 0)
            
            if q_val > 0:
                suma_cosechada = quicksum(
                    N[gps] * x[gps + (d,)]
                    for gps in GP
                    if TIPO[gps] == t and CAT.get(gps + (d,), None) == c
                )

                limite_inferior = (1 - tol) * q_val
                limite_superior = (1 + tol) * q_val

                # Restricción inferior
                model.addConstr(
                    suma_cosechada >= limite_inferior,
                    name=f"R2_inferior_{t}_{c}_{d}"
                )

                # Restricción superior
                model.addConstr(
                    suma_cosechada <= limite_superior,
                    name=f"R2_superior_{t}_{c}_{d}"
                )

# %%
# === 5. FUNCIÓN OBJETIVO ===

# MINIMIZAR la desviación diaria de cosecha con respecto a la demanda por conjuntos de pollo

model.setObjective(
    quicksum(dev[t, c, d] for t in T for c in C for d in D) +
    PENALIZACION * quicksum(violacion[t, c, d] for t in T for c in C for d in D),
    GRB.MINIMIZE
)

# %%
# Resolver el modelo
model.optimize()

#Revisar el estado del modelo de optimizacion
if model.status == GRB.OPTIMAL:
    print("\n✅ Solución óptima encontrada.")
elif model.status == GRB.INFEASIBLE:
    print("\n❌ El modelo es infactible.")
    model.computeIIS()
    model.write("modelo_infactible.ilp")
elif model.status == GRB.UNBOUNDED:
    print("\n❌ El modelo no está acotado.")
else:
    print(f"\n⚠️ El modelo terminó con estado: {model.status}")
# Out:
# Gurobi Optimizer version 12.0.2 build v12.0.2rc0 (win64 - Windows 11.0 (22621.2))
#
# CPU model: Intel(R) Core(TM) i7-1065G7 CPU @ 1.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Academic license 2680166 - for non-commercial use only - registered to 10___@u.icesi.edu.co
# Optimize a model with 1737 rows, 3148 columns and 19456 nonzeros
# Model fingerprint: 0xd7af85f2
# Variable types: 208 continuous, 2940 integer (2940 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+04]
#   Objective range  [1e+00, 1e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+06]
# Presolve removed 1400 rows and 1543 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
#
# ❌ El modelo es infactible.
# Academic license 2680166 - for non-commercial use only - registered to 10___@u.icesi.edu.co
# Gurobi Optimizer version 12.0.2 build v12.0.2rc0 (win64 - Windows 11.0 (22621.2))
#
# CPU model: Intel(R) Core(TM) i7-1065G7 CPU @ 1.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
#
# Computing Irreducible Inconsistent Subsystem (IIS)...
#
#            Constraints          |            Bounds           |  Runtime
#       Min       Max     Guess   |   Min       Max     Guess   |
# --------------------------------------------------------------------------
#         0      1734         -         0       208         -           0s
# Numerical troubles encountered during IIS computation
#         4         4         4         0         0         0           0s
#
# IIS computed: 4 constraints, 0 bounds
# IIS runtime: 0.06 seconds (0.02 work units)

# %%
if model.status == GRB.INFEASIBLE:    
    model.computeIIS()

    for c in model.getConstrs():
        if c.IISConstr:
            print(f"Restricción en IIS: {c.ConstrName}")


    for v in model.getVars():
        if v.IISLB:
            print(f"Límite inferior en IIS: {v.VarName} ≥ {v.LB}")
        if v.IISUB:
            print(f"Límite superior en IIS: {v.VarName} ≤ {v.UB}")
# Out:
# Academic license 2680166 - for non-commercial use only - registered to 10___@u.icesi.edu.co
# Gurobi Optimizer version 12.0.2 build v12.0.2rc0 (win64 - Windows 11.0 (22621.2))
#
# CPU model: Intel(R) Core(TM) i7-1065G7 CPU @ 1.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
#
# IIS computed: 4 constraints, 0 bounds
# IIS runtime: 0.00 seconds (0.00 work units)
# Restricción en IIS: R1_una_vez_LA ORQUIDEA_3_H
# Restricción en IIS: R1_una_vez_ALBORADA_3_M
# Restricción en IIS: R2_inferior_BLANCO_MEDIANO_2
# Restricción en IIS: R2_inferior_BLANCO_MEDIANO_3

# %%
#Resultados de la cosecha
if model.status == GRB.OPTIMAL:    
    print("\n📦 Grupos cosechados:")
    for g, p, s in GP:
        for d in D:
            var = x[g, p, s, d]
            if var.X > 0.5:
                print(f"Grupo ({g}, {p}, {s}) cosechado el día {d}")
else: print("\n❌ No hay modelo óptimo")
# Out:
# ❌ No hay modelo óptimo

# %%
#Desviaciones presentadas y cosecha diaria
if model.status == GRB.OPTIMAL:
    print("\n📉 Desviaciones en el cumplimiento del mix diario:")
    for t in T:
        for c in C:
            for d in D:
                # Calcula la cantidad realmente cosechada para este tipo, categoría y día
                cantidad_cosechada = sum(
                    N[gps] * x[gps + (d,)].X
                    for gps in GP
                    if TIPO[gps] == t and CAT.get(gps + (d,), None) == c
                )
                
                # Obtiene la desviación
                val = dev[t, c, d].X
                
                # Solo muestra si hay desviación significativa (> 0.01)
                if val > 0.01:
                    print(f"Tipo {t}, Categoría {c}, Día {d}: desviación = {val:.0f} aves, cosechado = {cantidad_cosechada:.0f} aves")
else: print("\n❌ No hay modelo óptimo")
# Out:
# ❌ No hay modelo óptimo

# %%
conteo_mediano = 0
for (g,p,s) in GP:
    for d in D:
        if CAT.get((g,p,s,d)) == "MEDIANO":
            conteo_mediano += 1

print(f"Hay {conteo_mediano} combinaciones grupo-día con categoría MEDIANO")
# Out:
# Hay 350 combinaciones grupo-día con categoría MEDIANO

# %%
#Guardar resultados en un CSV
import csv

if model.status == GRB.OPTIMAL:
    with open(f"resultados_cosecha_min{dias:.0f}.csv", "w", newline="") as f:
        writer = csv.writer(f)
        writer.writerow(["Granja", "Galpón", "Sexo", "Día", "Cosechado (1/0)"])
        for g, p, s in GP:
            for d in D:
                writer.writerow([g, p, s, d, int(x[g, p, s, d].X > 0.5)])
else: print("\n❌ No hay modelo óptimo")
# Out:
# ❌ No hay modelo óptimo

# %%
if model.status == GRB.OPTIMAL:
    with open(f"resultados_cosecha_min{dias:.0f}dias2.csv", "w", newline="") as f:
        writer = csv.writer(f)
        writer.writerow(["Granja", "Galpón", "Sexo", "Día", "Tipo", "Categoría", "Cosechado (1/0)", "Cantidad cosechada"])

        for g, p, s in GP:
            tipo = TIPO[(g, p, s)]
            for d in D:
                cat = CAT.get((g, p, s, d), "NA")
                cosechado = int(x[g, p, s, d].X > 0.5)
                cantidad = int(N[(g, p, s)] * x[g, p, s, d].X + 0.5) if cosechado else 0

                writer.writerow([g, p, s, d, tipo, cat, cosechado, cantidad])
else: print("\n❌ No hay modelo óptimo")
# Out:
# ❌ No hay modelo óptimo

# %% [markdown]
# ### Modelo con la función de maximización de ADG

# %%
# === 5. FUNCIÓN OBJETIVO ===

#MAXIMIZAR la ganancia de peso diaria penalizando la desviación de la demanda diaria de pollos
model.setObjective(
    quicksum(
        ADG[g, p, s, d] * N[g, p, s] * x[g, p, s, d]
        for (g, p, s) in GP
        for d in D
        if (g, p, s, d) in ADG
    ) - PENALIZACION * quicksum(dev[t, c, d] for t in T for c in C for d in D),
    GRB.MAXIMIZE
)

# %%
# Resolver el modelo
model.optimize()

#Revisar el estado del modelo de optimizacion
if model.status == GRB.OPTIMAL:
    print("\n✅ Solución óptima encontrada.")
elif model.status == GRB.INFEASIBLE:
    print("\n❌ El modelo es infactible.")
    model.computeIIS()
    model.write("modelo_infactible.ilp")
elif model.status == GRB.UNBOUNDED:
    print("\n❌ El modelo no está acotado.")
else:
    print(f"\n⚠️ El modelo terminó con estado: {model.status}")
# Out:
# Gurobi Optimizer version 12.0.2 build v12.0.2rc0 (win64 - Windows 11.0 (22621.2))
#
# CPU model: Intel(R) Core(TM) i7-1065G7 CPU @ 1.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Academic license 2680166 - for non-commercial use only - registered to 10___@u.icesi.edu.co
# Optimize a model with 1737 rows, 3148 columns and 19456 nonzeros
# Model fingerprint: 0x2e3139c7
# Variable types: 208 continuous, 2940 integer (2940 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+04]
#   Objective range  [1e+04, 2e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+06]
# Presolve removed 1400 rows and 1543 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 0
# No other solutions better than -1e+100
#
# Model is infeasible
# Best objective -, best bound -, gap -
#
# ❌ El modelo es infactible.
# Academic license 2680166 - for non-commercial use only - registered to 10___@u.icesi.edu.co
# Gurobi Optimizer version 12.0.2 build v12.0.2rc0 (win64 - Windows 11.0 (22621.2))
#
# CPU model: Intel(R) Core(TM) i7-1065G7 CPU @ 1.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
#
# Computing Irreducible Inconsistent Subsystem (IIS)...
#
#            Constraints          |            Bounds           |  Runtime
#       Min       Max     Guess   |   Min       Max     Guess   |
# --------------------------------------------------------------------------
#         0      1734         -         0       208         -           0s
# Numerical troubles encountered during IIS computation
#         4         4         4         0         0         0           0s
#
# IIS computed: 4 constraints, 0 bounds
# IIS runtime: 0.07 seconds (0.02 work units)

# %%
#Resultados de la cosecha

if model.status == GRB.OPTIMAL:
    print("\n📦 Grupos cosechados:")
    for g, p, s in GP:
        for d in D:
            var = x[g, p, s, d]
            if var.X > 0.5:
                print(f"Grupo ({g}, {p}, {s}) cosechado el día {d}")
else: print("\n❌ No hay modelo óptimo")
# Out:
# ❌ No hay modelo óptimo

# %%
#Desviaciones presentadas y cosecha diaria

if model.status == GRB.OPTIMAL:
    print("\n📉 Desviaciones en el cumplimiento del mix diario:")
    for t in T:
        for c in C:
            for d in D:
                # Calcula la cantidad realmente cosechada para este tipo, categoría y día
                cantidad_cosechada = sum(
                    N[gps] * x[gps + (d,)].X
                    for gps in GP
                    if TIPO[gps] == t and CAT.get(gps + (d,), None) == c
                )
                
                # Obtiene la desviación
                val = dev[t, c, d].X
                
                # Solo muestra si hay desviación significativa (> 0.01)
                if val > 0.01:
                    print(f"Tipo {t}, Categoría {c}, Día {d}: desviación = {val:.0f} aves, cosechado = {cantidad_cosechada:.0f} aves")
else: print("\n❌ No hay modelo óptimo")
# Out:
# ❌ No hay modelo óptimo

# %%
if model.status == GRB.INFEASIBLE:    
    model.computeIIS()

    for c in model.getConstrs():
        if c.IISConstr:
            print(f"Restricción en IIS: {c.ConstrName}")


    for v in model.getVars():
        if v.IISLB:
            print(f"Límite inferior en IIS: {v.VarName} ≥ {v.LB}")
        if v.IISUB:
            print(f"Límite superior en IIS: {v.VarName} ≤ {v.UB}")
# Out:
# Academic license 2680166 - for non-commercial use only - registered to 10___@u.icesi.edu.co
# Gurobi Optimizer version 12.0.2 build v12.0.2rc0 (win64 - Windows 11.0 (22621.2))
#
# CPU model: Intel(R) Core(TM) i7-1065G7 CPU @ 1.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
#
# IIS computed: 4 constraints, 0 bounds
# IIS runtime: 0.00 seconds (0.00 work units)
# Restricción en IIS: R1_una_vez_LA ORQUIDEA_3_H
# Restricción en IIS: R1_una_vez_ALBORADA_3_M
# Restricción en IIS: R2_inferior_BLANCO_MEDIANO_2
# Restricción en IIS: R2_inferior_BLANCO_MEDIANO_3

# %%
#Guardar resultados en un CSV
import csv
if model.status == GRB.OPTIMAL:
    with open(f"resultados_cosecha_max{dias:.0f}dias.csv", "w", newline="") as f:
        writer = csv.writer(f)
        writer.writerow(["Granja", "Galpón", "Sexo", "Día", "Cosechado (1/0)"])
        for g, p, s in GP:
            for d in D:
                writer.writerow([g, p, s, d, int(x[g, p, s, d].X > 0.5)])
else: print("\n❌ No hay modelo óptimo")
# Out:
# ❌ No hay modelo óptimo

# %%
import csv

if model.status == GRB.OPTIMAL:
    with open(f"resultados_cosecha_max{dias:.0f}.csv", "w", newline="") as f:
        writer = csv.writer(f)
        writer.writerow(["Granja", "Galpón", "Sexo", "Día", "Tipo", "Categoría", "Cosechado (1/0)", "Cantidad cosechada"])

        for g, p, s in GP:
            tipo = TIPO[(g, p, s)]
            for d in D:
                cat = CAT.get((g, p, s, d), "NA")
                cosechado = int(x[g, p, s, d].X > 0.5)
                cantidad = int(N[(g, p, s)] * x[g, p, s, d].X + 0.5) if cosechado else 0

                writer.writerow([g, p, s, d, tipo, cat, cosechado, cantidad])
else: print("\n❌ No hay modelo óptimo")
# Out:
# ❌ No hay modelo óptimo

# %% [markdown]
# ### Modelo con restricción de cumplimiento semanal por tipo y categoría de peso

# %%
# === Calcula semanal de la demanda por categoría

Q_semanal = {}

for (t, c, d), val in Q.items():
    semana = MAPD.get(d)  # Obtener la semana a la que pertenece el día d
    if semana is not None:
        Q_semanal[(t, c, semana)] = Q_semanal.get((t, c, semana), 0) + val

# %%
# === R10. RESTRICCION SEMANAL DE DEMANDA DE POLLOS POR TIPO Y CATEGORIA

for t in T:
    for c in ["PEQUEÑO", "MEDIANO"]:  # Solo aplica a estas categorías
        for s in WEEK:
            q_total = Q_semanal.get((t, c, s), 0)

            if q_total > 0:
                dias_semana = [d for d in D if MAPD.get(d) == s]

                suma_cosechada = quicksum(
                    N[gps] * x[gps + (d,)]
                    for gps in GP
                    for d in dias_semana
                    if TIPO[gps] == t and CAT.get(gps + (d,), None) == c
                )

                limite_inferior = (1 - tol) * q_total
                limite_superior = (1 + tol) * q_total

                # Restricción inferior
                model.addConstr(
                    suma_cosechada >= limite_inferior,
                    name=f"R2sem_inferior_{t}_{c}_sem{s}"
                )

                # Restricción superior
                model.addConstr(
                    suma_cosechada <= limite_superior,
                    name=f"R2sem_superior_{t}_{c}_sem{s}"
                )

# %%
# Definición de la variable de desviación semanal
desv2 = model.addVars(T, C, WEEK, vtype=GRB.CONTINUOUS, name="desv2")

#Definición de la desviación
for t in T:
    for c in ["PEQUEÑO", "MEDIANO"]:
        for s in WEEK:
            q_total = Q_semanal.get((t, c, s), 0)
            if q_total > 0:
                dias_semana = [d for d in D if MAPD.get(d) == s]

                cantidad_real = quicksum(
                    N[gps] * x[gps + (d,)]
                    for gps in GP
                    for d in dias_semana
                    if TIPO[gps] == t and CAT.get(gps + (d,), None) == c
                )

                model.addConstr(desv2[t, c, s] >= cantidad_real - q_total,
                                name=f"desv_pos_{t}_{c}_sem{s}")
                model.addConstr(desv2[t, c, s] >= q_total - cantidad_real,
                                name=f"desv_neg_{t}_{c}_sem{s}")

# %%
# === 5.3. FUNCION OBJETIVO DE MINIMIZACIÓN DE DESVIACIÓN SEMANAL ===

model.setObjective(
    quicksum(desv2[t, c, s] for t in T for c in ["PEQUEÑO", "MEDIANO"] for s in WEEK),
    GRB.MINIMIZE
)

# %%
# Resolver el modelo
model.optimize()

#Revisar el estado del modelo de optimizacion
if model.status == GRB.OPTIMAL:
    print("\n✅ Solución óptima encontrada.")
elif model.status == GRB.INFEASIBLE:
    print("\n❌ El modelo es infactible.")
    model.computeIIS()
    model.write("modelo_infactible.ilp")
elif model.status == GRB.UNBOUNDED:
    print("\n❌ El modelo no está acotado.")
else:
    print(f"\n⚠️ El modelo terminó con estado: {model.status}")
# Out:
# Gurobi Optimizer version 12.0.2 build v12.0.2rc0 (win64 - Windows 11.0 (22621.2))
#
# CPU model: Intel(R) Core(TM) i7-1065G7 CPU @ 1.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Academic license 2680166 - for non-commercial use only - registered to 10___@u.icesi.edu.co
# Optimize a model with 1753 rows, 3164 columns and 22884 nonzeros
# Model fingerprint: 0xd6de22de
# Variable types: 224 continuous, 2940 integer (2940 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+06]
# Presolve removed 1400 rows and 1555 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
#
# ❌ El modelo es infactible.
# Academic license 2680166 - for non-commercial use only - registered to 10___@u.icesi.edu.co
# Gurobi Optimizer version 12.0.2 build v12.0.2rc0 (win64 - Windows 11.0 (22621.2))
#
# CPU model: Intel(R) Core(TM) i7-1065G7 CPU @ 1.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
#
# Computing Irreducible Inconsistent Subsystem (IIS)...
#
#            Constraints          |            Bounds           |  Runtime
#       Min       Max     Guess   |   Min       Max     Guess   |
# --------------------------------------------------------------------------
#         0      1750         -         0       224         -           0s
# Numerical troubles encountered during IIS computation
#         5         5         5         0         0         0           0s
#
# IIS computed: 5 constraints, 0 bounds
# IIS runtime: 0.05 seconds (0.02 work units)

# %%
#Resultados de la cosecha

if model.status == GRB.OPTIMAL:
    print("\n📦 Grupos cosechados:")
    for g, p, s in GP:
        for d in D:
            var = x[g, p, s, d]
            if var.X > 0.5:
                print(f"Grupo ({g}, {p}, {s}) cosechado el día {d}")
else: print("\n❌ No hay modelo óptimo")
# Out:
# ❌ No hay modelo óptimo

# %%
#Desviaciones presentadas y cosecha diaria

if model.status == GRB.OPTIMAL:
    print("\n📉 Desviaciones en el cumplimiento del mix diario:")
    for t in T:
        for c in C:
            for d in D:
                # Calcula la cantidad realmente cosechada para este tipo, categoría y día
                cantidad_cosechada = sum(
                    N[gps] * x[gps + (d,)].X
                    for gps in GP
                    if TIPO[gps] == t and CAT.get(gps + (d,), None) == c
                )
                
                # Obtiene la desviación
                val = dev[t, c, d].X
                
                # Solo muestra si hay desviación significativa (> 0.01)
                if val > 0.01:
                    print(f"Tipo {t}, Categoría {c}, Día {d}: desviación = {val:.0f} aves, cosechado = {cantidad_cosechada:.0f} aves")
else: print("\n❌ No hay modelo óptimo")
# Out:
# ❌ No hay modelo óptimo

# %%
if model.status == GRB.INFEASIBLE:    
    model.computeIIS()

    for c in model.getConstrs():
        if c.IISConstr:
            print(f"Restricción en IIS: {c.ConstrName}")


    for v in model.getVars():
        if v.IISLB:
            print(f"Límite inferior en IIS: {v.VarName} ≥ {v.LB}")
        if v.IISUB:
            print(f"Límite superior en IIS: {v.VarName} ≤ {v.UB}")
# Out:
# Academic license 2680166 - for non-commercial use only - registered to 10___@u.icesi.edu.co
# Gurobi Optimizer version 12.0.2 build v12.0.2rc0 (win64 - Windows 11.0 (22621.2))
#
# CPU model: Intel(R) Core(TM) i7-1065G7 CPU @ 1.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
#
# IIS computed: 5 constraints, 0 bounds
# IIS runtime: 0.00 seconds (0.00 work units)
# Restricción en IIS: R1_una_vez_LA ORQUIDEA_2_MX
# Restricción en IIS: R1_una_vez_ALBORADA_3_M
# Restricción en IIS: R2_inferior_BLANCO_MEDIANO_1
# Restricción en IIS: R2_inferior_BLANCO_MEDIANO_2
# Restricción en IIS: R2_inferior_BLANCO_MEDIANO_3

# %%
#Guardar resultados en un CSV
import csv
if model.status == GRB.OPTIMAL:
    with open(f"resultados_cosecha_sem_max{dias:.0f}dias.csv", "w", newline="") as f:
        writer = csv.writer(f)
        writer.writerow(["Granja", "Galpón", "Sexo", "Día", "Cosechado (1/0)"])
        for g, p, s in GP:
            for d in D:
                writer.writerow([g, p, s, d, int(x[g, p, s, d].X > 0.5)])
else: print("\n❌ No hay modelo óptimo")
# Out:
# ❌ No hay modelo óptimo

# %%
import csv

if model.status == GRB.OPTIMAL:
    with open(f"resultados_cosecha_sem_max{dias:.0f}.csv", "w", newline="") as f:
        writer = csv.writer(f)
        writer.writerow(["Granja", "Galpón", "Sexo", "Día", "Tipo", "Categoría", "Cosechado (1/0)", "Cantidad cosechada"])

        for g, p, s in GP:
            tipo = TIPO[(g, p, s)]
            for d in D:
                cat = CAT.get((g, p, s, d), "NA")
                cosechado = int(x[g, p, s, d].X > 0.5)
                cantidad = int(N[(g, p, s)] * x[g, p, s, d].X + 0.5) if cosechado else 0

                writer.writerow([g, p, s, d, tipo, cat, cosechado, cantidad])
else: print("\n❌ No hay modelo óptimo")
# Out:
# ❌ No hay modelo óptimo

# %%
for c in model.getConstrs():
    print(c.ConstrName)
# Out:
# R1_una_vez_MAO_5_M
# R1_una_vez_MAO_6_M
# R1_una_vez_LA CHAMBA_1_M
# R1_una_vez_LA CHAMBA_2_M
# R1_una_vez_LA CHAMBA_3_M
# R1_una_vez_LA CHAMBA_4_M
# R1_una_vez_CHICO_3_M
# R1_una_vez_RANCHO ALEGRE_1_M
# R1_una_vez_RANCHO ALEGRE_2_M
# R1_una_vez_RANCHO ALEGRE_3_M
# R1_una_vez_RANCHO ALEGRE_4_M
# R1_una_vez_POTOCO_1_M
# R1_una_vez_POTOCO_2_M
# R1_una_vez_POTOCO_3_M
# R1_una_vez_POTOCO_4_M
# R1_una_vez_POTOCO_5_M
# R1_una_vez_POTOCO_6_M
# R1_una_vez_POTOCO_7_M
# R1_una_vez_POTOCO_8_M
# R1_una_vez_POTOCO_9_M
# R1_una_vez_ARANJUEZ_1_M
# R1_una_vez_ARANJUEZ_4_M
# R1_una_vez_ARANJUEZ_5_M
# R1_una_vez_ARANJUEZ_6_M
# R1_una_vez_ARANJUEZ_7_M
# R1_una_vez_NIÑA MARIA_1_M
# R1_una_vez_NIÑA MARIA_2_M
# R1_una_vez_NIÑA MARIA_3_M
# R1_una_vez_LA ORQUIDEA_1_M
# R1_una_vez_LA ORQUIDEA_2_MX
# R1_una_vez_LA ORQUIDEA_3_H
# R1_una_vez_MARGARITA_1_M
# R1_una_vez_MARGARITA_2_M
# R1_una_vez_MARGARITA_3_M
# R1_una_vez_MARGARITA_4_M
# R1_una_vez_TAMINANGO_1_M
# R1_una_vez_TAMINANGO_2_M
# R1_una_vez_TAMINANGO_3_M
# R1_una_vez_TAMINANGO_4_M
# R1_una_vez_SAN BUENO_1_M
# R1_una_vez_SAN BUENO_2_M
# R1_una_vez_SAN BUENO_3_M
# R1_una_vez_SAN BUENO_4_M
# R1_una_vez_SAN BUENO_4_H
# R1_una_vez_SAN BUENO_5_M
# R1_una_vez_SAN BUENO_5_H
# R1_una_vez_SAN BUENO_6_M
# R1_una_vez_SAN BUENO_6_H
# R1_una_vez_SAN BUENO_7_M
# R1_una_vez_SAN BUENO_7_H
# R1_una_vez_SAN BUENO_8_H
# R1_una_vez_EL MARMOL_1_H
# R1_una_vez_EL MARMOL_2_M
# R1_una_vez_SANTA MONICA_1_M
# R1_una_vez_SANTA MONICA_1_H
# R1_una_vez_SANTA MONICA_2_M
# R1_una_vez_SANTA MONICA_2_H
# R1_una_vez_SANTA MONICA_3_M
# R1_una_vez_SANTA MONICA_3_H
# R1_una_vez_SANTA MONICA_4_M
# R1_una_vez_SANTA MONICA_4_H
# R1_una_vez_SANTA MONICA_5_M
# R1_una_vez_SANTA MONICA_5_H
# R1_una_vez_SANTA MONICA_6_M
# R1_una_vez_SANTA MONICA_6_H
# R1_una_vez_SANTA MONICA_7_M
# R1_una_vez_SANTA MONICA_7_H
# R1_una_vez_SANTA MONICA_8_M
# R1_una_vez_SANTA MONICA_8_H
# R1_una_vez_SANTA MONICA_9_M
# R1_una_vez_SANTA MONICA_9_H
# R1_una_vez_SANTA MONICA_10_M
# R1_una_vez_SANTA MONICA_10_H
# R1_una_vez_SANTA MONICA_11_M
# R1_una_vez_SANTA MONICA_11_H
# R1_una_vez_EL MARMOL_3_M
# R1_una_vez_EL MARMOL_4_H
# R1_una_vez_EL MARMOL_5_H
# R1_una_vez_CETEC SANTA ROSA_1_MX
# R1_una_vez_CETEC SANTA ROSA_2_MX
# R1_una_vez_CETEC SANTA ROSA_3_MX
# R1_una_vez_CETEC SANTA ROSA_4_MX
# R1_una_vez_CETEC SANTA ROSA_5_MX
# R1_una_vez_CETEC SANTA ROSA_6_MX
# R1_una_vez_VALLE DE ORO_1_M
# R1_una_vez_VALLE DE ORO_1_H
# R1_una_vez_VALLE DE ORO_2_M
# R1_una_vez_VALLE DE ORO_2_H
# R1_una_vez_VALLE DE ORO_3_M
# R1_una_vez_VALLE DE ORO_3_H
# R1_una_vez_VALLE DE ORO_4_M
# R1_una_vez_VALLE DE ORO_4_H
# R1_una_vez_VALLE DE ORO_5_M
# R1_una_vez_VALLE DE ORO_5_H
# R1_una_vez_VALLE DE ORO_6_M
# R1_una_vez_VALLE DE ORO_6_H
# R1_una_vez_VALLE DE ORO_7_M
# R1_una_vez_VALLE DE ORO_7_H
# R1_una_vez_VALLE DE ORO_8_M
# R1_una_vez_VALLE DE ORO_8_H
# R1_una_vez_VALLE DE ORO_9_M
# R1_una_vez_VALLE DE ORO_9_H
# R1_una_vez_VALLE DE ORO_10_M
# R1_una_vez_VALLE DE ORO_10_H
# R1_una_vez_CARACOLI_1_M
# R1_una_vez_CARACOLI_1_H
# R1_una_vez_CARACOLI_2_M
# R1_una_vez_CARACOLI_2_H
# R1_una_vez_LA JUANA_4_M
# R1_una_vez_LA JUANA_4_H
# R1_una_vez_LA JUANA_5_M
# R1_una_vez_LA JUANA_5_H
# R1_una_vez_RECREO_1_M
# R1_una_vez_RECREO_1_H
# R1_una_vez_RECREO_2_M
# R1_una_vez_RECREO_2_H
# R1_una_vez_RECREO_3_M
# R1_una_vez_RECREO_4_M
# R1_una_vez_RECREO_5_H
# R1_una_vez_RECREO_6_H
# R1_una_vez_ALBORADA_1_H
# R1_una_vez_ALBORADA_2_H
# R1_una_vez_ALBORADA_3_M
# R1_una_vez_ALBORADA_4_M
# R1_una_vez_DON SEBASTIAN_1_M
# R1_una_vez_DON SEBASTIAN_2_H
# R1_una_vez_DON SEBASTIAN_3_H
# R1_una_vez_DON SEBASTIAN_4_M
# R1_una_vez_DON SEBASTIAN_4_H
# R1_una_vez_DON SEBASTIAN_5_M
# R1_una_vez_DON SEBASTIAN_5_H
# R1_una_vez_DON SEBASTIAN_6_M
# R1_una_vez_DON SEBASTIAN_6_H
# R1_una_vez_EL EDEN_8_M
# R1_una_vez_EL EDEN_8_H
# R1_una_vez_EL EDEN_9_M
# R1_una_vez_EL EDEN_9_H
# R1_una_vez_EL EDEN_10_M
# R1_una_vez_EL EDEN_10_H
# R1_una_vez_EL EDEN_11_M
# R1_una_vez_EL EDEN_11_H
# R1_una_vez_LA JUANA_1_H
# R1_una_vez_LA JUANA_2_M
# R1_una_vez_LA JUANA_3_M
# R1_una_vez_LA JUANA_3_H
# R1_una_vez_LA GUAQUITA_2_M
# R1_una_vez_LA GUAQUITA_3_H
# R1_una_vez_MONTE OSCURO_5_M
# R1_una_vez_MONTE OSCURO_5_H
# R1_una_vez_MONTE OSCURO_6_M
# R1_una_vez_MONTE OSCURO_6_H
# R1_una_vez_MONTE OSCURO_1_M
# R1_una_vez_MONTE OSCURO_1_H
# R1_una_vez_MONTE OSCURO_2_M
# R1_una_vez_MONTE OSCURO_2_H
# R1_una_vez_MONTE OSCURO_3_M
# R1_una_vez_MONTE OSCURO_3_H
# R1_una_vez_MONTE OSCURO_4_M
# R1_una_vez_MONTE OSCURO_4_H
# R1_una_vez_ABISINIA_1_M
# R1_una_vez_ABISINIA_2_M
# R1_una_vez_ABISINIA_3_H
# R1_una_vez_ABISINIA_4_H
# R1_una_vez_LA GUAQUITA_1_H
# R1_una_vez_LA GUAQUITA_4_M
# R1_una_vez_LA GUAQUITA_5_M
# R1_una_vez_LA REINA_1_M
# R1_una_vez_LA REINA_1_H
# R1_una_vez_ABISINIA_5_M
# R1_una_vez_ABISINIA_5_H
# R1_una_vez_ABISINIA_6_M
# R1_una_vez_ABISINIA_6_H
# R1_una_vez_ABISINIA_7_M
# R1_una_vez_ABISINIA_7_H
# R1_una_vez_ABISINIA_8_M
# R1_una_vez_ABISINIA_8_H
# R1_una_vez_ABISINIA_9_M
# R1_una_vez_ABISINIA_9_H
# R1_una_vez_ABISINIA_10_M
# R1_una_vez_ABISINIA_10_H
# R1_una_vez_CETEC ESCUELA VERDE_1_MX
# R1_una_vez_CETEC ESCUELA VERDE_2_MX
# R1_una_vez_EL ENCANTO_1_H
# R1_una_vez_EL ENCANTO_2_H
# R1_una_vez_EL ENCANTO_3_H
# R1_una_vez_EL ENCANTO_4_H
# R1_una_vez_EL ENCANTO_5_H
# R1_una_vez_EL ENCANTO_7_M
# R1_una_vez_EL ENCANTO_8_M
# R1_una_vez_EL ENCANTO_9_M
# R1_una_vez_EL ENCANTO_17_M
# R1_una_vez_EL ENCANTO_17_H
# R1_una_vez_EL ENCANTO_18_M
# R1_una_vez_EL ENCANTO_18_H
# R1_una_vez_LA AMANDA_1_M
# R1_una_vez_LA AMANDA_2_M
# R1_una_vez_LA AMANDA_3_H
# R1_una_vez_LA AMANDA_4_H
# R1_una_vez_LA AMANDA_5_M
# R1_una_vez_LA AMANDA_6_H
# R1_una_vez_LA AMANDA_7_H
# R1_una_vez_LA CABAÑITA_1_H
# R1_una_vez_LA CABAÑITA_2_H
# R1_una_vez_LA CABAÑITA_3_H
# R1_una_vez_LA CABAÑITA_4_M
# R1_una_vez_LA CABAÑITA_5_MX
# R1_una_vez_LA CABAÑITA_6_M
# R1_una_vez_LA CABAÑITA_7_M
# R1_una_vez_BUENOS AIRES_1_H
# R1_una_vez_BUENOS AIRES_2_H
# R1_una_vez_BUENOS AIRES_3_M
# R1_una_vez_BUENOS AIRES_6_M
# R1_una_vez_BUENOS AIRES_7_H
# R1_una_vez_EL ENCANTO_6_M
# R1_una_vez_EL ENCANTO_6_H
# R1_una_vez_EL ENCANTO_10_M
# R1_una_vez_EL ENCANTO_10_H
# R1_una_vez_EL ENCANTO_11_M
# R1_una_vez_EL ENCANTO_11_H
# R1_una_vez_EL ENCANTO_12_M
# R1_una_vez_EL ENCANTO_12_H
# R1_una_vez_EL ENCANTO_13_M
# R1_una_vez_EL ENCANTO_13_H
# R1_una_vez_EL ENCANTO_14_M
# R1_una_vez_EL ENCANTO_14_H
# R1_una_vez_EL ENCANTO_15_M
# R1_una_vez_EL ENCANTO_15_H
# R1_una_vez_EL ENCANTO_16_M
# R1_una_vez_EL ENCANTO_16_H
# R1_una_vez_BUENOS AIRES_4_M
# R1_una_vez_BUENOS AIRES_5_H
# R1_una_vez_CETEC SAN NICOLAS_1_MX
# R1_una_vez_CETEC CRUCERO_1_MX
# R1_una_vez_VILLA DEL LAGO_1_M
# R1_una_vez_VILLA DEL LAGO_1_H
# R1_una_vez_VILLA DEL LAGO_2_M
# R1_una_vez_VILLA DEL LAGO_2_H
# R1_una_vez_VILLA DEL LAGO_3_M
# R1_una_vez_VILLA DEL LAGO_3_H
# R1_una_vez_VILLA DEL LAGO_4_M
# R1_una_vez_VILLA DEL LAGO_4_H
# R1_una_vez_VILLA DEL LAGO_5_M
# R1_una_vez_VILLA DEL LAGO_5_H
# R1_una_vez_VILLA DEL LAGO_6_M
# R1_una_vez_VILLA DEL LAGO_6_H
# R5_inferior_1
# R5_superior_1
# R5_inferior_2
# R5_superior_2
# R_peso_maximo_MAO_5_M_6
# R_peso_maximo_MAO_5_M_7
# R_peso_maximo_MAO_5_M_8
# R_peso_maximo_MAO_5_M_9
# R_peso_maximo_MAO_5_M_10
# R_peso_maximo_MAO_5_M_11
# R_peso_maximo_MAO_5_M_12
# R_peso_maximo_MAO_6_M_6
# R_peso_maximo_MAO_6_M_7
# R_peso_maximo_MAO_6_M_8
# R_peso_maximo_MAO_6_M_9
# R_peso_maximo_MAO_6_M_10
# R_peso_maximo_MAO_6_M_11
# R_peso_maximo_MAO_6_M_12
# R_peso_maximo_LA CHAMBA_1_M_4
# R_peso_maximo_LA CHAMBA_1_M_5
# R_peso_maximo_LA CHAMBA_1_M_6
# R_peso_maximo_LA CHAMBA_1_M_7
# R_peso_maximo_LA CHAMBA_1_M_8
# R_peso_maximo_LA CHAMBA_1_M_9
# R_peso_maximo_LA CHAMBA_1_M_10
# R_peso_maximo_LA CHAMBA_1_M_11
# R_peso_maximo_LA CHAMBA_1_M_12
# R_peso_maximo_LA CHAMBA_2_M_4
# R_peso_maximo_LA CHAMBA_2_M_5
# R_peso_maximo_LA CHAMBA_2_M_6
# R_peso_maximo_LA CHAMBA_2_M_7
# R_peso_maximo_LA CHAMBA_2_M_8
# R_peso_maximo_LA CHAMBA_2_M_9
# R_peso_maximo_LA CHAMBA_2_M_10
# R_peso_maximo_LA CHAMBA_2_M_11
# R_peso_maximo_LA CHAMBA_2_M_12
# R_peso_maximo_LA CHAMBA_3_M_4
# R_peso_maximo_LA CHAMBA_3_M_5
# R_peso_maximo_LA CHAMBA_3_M_6
# R_peso_maximo_LA CHAMBA_3_M_7
# R_peso_maximo_LA CHAMBA_3_M_8
# R_peso_maximo_LA CHAMBA_3_M_9
# R_peso_maximo_LA CHAMBA_3_M_10
# R_peso_maximo_LA CHAMBA_3_M_11
# R_peso_maximo_LA CHAMBA_3_M_12
# R_peso_maximo_LA CHAMBA_4_M_4
# R_peso_maximo_LA CHAMBA_4_M_5
# R_peso_maximo_LA CHAMBA_4_M_6
# R_peso_maximo_LA CHAMBA_4_M_7
# R_peso_maximo_LA CHAMBA_4_M_8
# R_peso_maximo_LA CHAMBA_4_M_9
# R_peso_maximo_LA CHAMBA_4_M_10
# R_peso_maximo_LA CHAMBA_4_M_11
# R_peso_maximo_LA CHAMBA_4_M_12
# R_peso_maximo_CHICO_3_M_10
# R_peso_maximo_CHICO_3_M_11
# R_peso_maximo_CHICO_3_M_12
# R_peso_maximo_RANCHO ALEGRE_1_M_5
# R_peso_maximo_RANCHO ALEGRE_1_M_6
# R_peso_maximo_RANCHO ALEGRE_1_M_7
# R_peso_maximo_RANCHO ALEGRE_1_M_8
# R_peso_maximo_RANCHO ALEGRE_1_M_9
# R_peso_maximo_RANCHO ALEGRE_1_M_10
# R_peso_maximo_RANCHO ALEGRE_1_M_11
# R_peso_maximo_RANCHO ALEGRE_1_M_12
# R_peso_maximo_RANCHO ALEGRE_2_M_5
# R_peso_maximo_RANCHO ALEGRE_2_M_6
# R_peso_maximo_RANCHO ALEGRE_2_M_7
# R_peso_maximo_RANCHO ALEGRE_2_M_8
# R_peso_maximo_RANCHO ALEGRE_2_M_9
# R_peso_maximo_RANCHO ALEGRE_2_M_10
# R_peso_maximo_RANCHO ALEGRE_2_M_11
# R_peso_maximo_RANCHO ALEGRE_2_M_12
# R_peso_maximo_RANCHO ALEGRE_3_M_5
# R_peso_maximo_RANCHO ALEGRE_3_M_6
# R_peso_maximo_RANCHO ALEGRE_3_M_7
# R_peso_maximo_RANCHO ALEGRE_3_M_8
# R_peso_maximo_RANCHO ALEGRE_3_M_9
# R_peso_maximo_RANCHO ALEGRE_3_M_10
# R_peso_maximo_RANCHO ALEGRE_3_M_11
# R_peso_maximo_RANCHO ALEGRE_3_M_12
# R_peso_maximo_RANCHO ALEGRE_4_M_5
# R_peso_maximo_RANCHO ALEGRE_4_M_6
# R_peso_maximo_RANCHO ALEGRE_4_M_7
# R_peso_maximo_RANCHO ALEGRE_4_M_8
# R_peso_maximo_RANCHO ALEGRE_4_M_9
# R_peso_maximo_RANCHO ALEGRE_4_M_10
# R_peso_maximo_RANCHO ALEGRE_4_M_11
# R_peso_maximo_RANCHO ALEGRE_4_M_12
# R_peso_maximo_POTOCO_1_M_10
# R_peso_maximo_POTOCO_1_M_11
# R_peso_maximo_POTOCO_1_M_12
# R_peso_maximo_POTOCO_2_M_10
# R_peso_maximo_POTOCO_2_M_11
# R_peso_maximo_POTOCO_2_M_12
# R_peso_maximo_POTOCO_3_M_10
# R_peso_maximo_POTOCO_3_M_11
# R_peso_maximo_POTOCO_3_M_12
# R_peso_maximo_POTOCO_4_M_10
# R_peso_maximo_POTOCO_4_M_11
# R_peso_maximo_POTOCO_4_M_12
# R_peso_maximo_POTOCO_5_M_10
# R_peso_maximo_POTOCO_5_M_11
# R_peso_maximo_POTOCO_5_M_12
# R_peso_maximo_POTOCO_6_M_10
# R_peso_maximo_POTOCO_6_M_11
# R_peso_maximo_POTOCO_6_M_12
# R_peso_maximo_POTOCO_7_M_10
# R_peso_maximo_POTOCO_7_M_11
# R_peso_maximo_POTOCO_7_M_12
# R_peso_maximo_POTOCO_8_M_10
# R_peso_maximo_POTOCO_8_M_11
# R_peso_maximo_POTOCO_8_M_12
# R_peso_maximo_POTOCO_9_M_10
# R_peso_maximo_POTOCO_9_M_11
# R_peso_maximo_POTOCO_9_M_12
# R_peso_maximo_ARANJUEZ_1_M_10
# R_peso_maximo_ARANJUEZ_1_M_11
# R_peso_maximo_ARANJUEZ_1_M_12
# R_peso_maximo_ARANJUEZ_4_M_10
# R_peso_maximo_ARANJUEZ_4_M_11
# R_peso_maximo_ARANJUEZ_4_M_12
# R_peso_maximo_ARANJUEZ_5_M_10
# R_peso_maximo_ARANJUEZ_5_M_11
# R_peso_maximo_ARANJUEZ_5_M_12
# R_peso_maximo_ARANJUEZ_6_M_10
# R_peso_maximo_ARANJUEZ_6_M_11
# R_peso_maximo_ARANJUEZ_6_M_12
# R_peso_maximo_ARANJUEZ_7_M_10
# R_peso_maximo_ARANJUEZ_7_M_11
# R_peso_maximo_ARANJUEZ_7_M_12
# R_peso_maximo_NIÑA MARIA_1_M_8
# R_peso_maximo_NIÑA MARIA_1_M_9
# R_peso_maximo_NIÑA MARIA_1_M_10
# R_peso_maximo_NIÑA MARIA_1_M_11
# R_peso_maximo_NIÑA MARIA_1_M_12
# R_peso_maximo_NIÑA MARIA_2_M_8
# R_peso_maximo_NIÑA MARIA_2_M_9
# R_peso_maximo_NIÑA MARIA_2_M_10
# R_peso_maximo_NIÑA MARIA_2_M_11
# R_peso_maximo_NIÑA MARIA_2_M_12
# R_peso_maximo_NIÑA MARIA_3_M_8
# R_peso_maximo_NIÑA MARIA_3_M_9
# R_peso_maximo_NIÑA MARIA_3_M_10
# R_peso_maximo_NIÑA MARIA_3_M_11
# R_peso_maximo_NIÑA MARIA_3_M_12
# R_peso_maximo_LA ORQUIDEA_1_M_12
# R_peso_maximo_MARGARITA_1_M_10
# R_peso_maximo_MARGARITA_1_M_11
# R_peso_maximo_MARGARITA_1_M_12
# R_peso_maximo_MARGARITA_2_M_10
# R_peso_maximo_MARGARITA_2_M_11
# R_peso_maximo_MARGARITA_2_M_12
# R_peso_maximo_MARGARITA_3_M_10
# R_peso_maximo_MARGARITA_3_M_11
# R_peso_maximo_MARGARITA_3_M_12
# R_peso_maximo_MARGARITA_4_M_10
# R_peso_maximo_MARGARITA_4_M_11
# R_peso_maximo_MARGARITA_4_M_12
# R_peso_maximo_TAMINANGO_1_M_8
# R_peso_maximo_TAMINANGO_1_M_9
# R_peso_maximo_TAMINANGO_1_M_10
# R_peso_maximo_TAMINANGO_1_M_11
# R_peso_maximo_TAMINANGO_1_M_12
# R_peso_maximo_TAMINANGO_2_M_8
# R_peso_maximo_TAMINANGO_2_M_9
# R_peso_maximo_TAMINANGO_2_M_10
# R_peso_maximo_TAMINANGO_2_M_11
# R_peso_maximo_TAMINANGO_2_M_12
# R_peso_maximo_TAMINANGO_3_M_8
# R_peso_maximo_TAMINANGO_3_M_9
# R_peso_maximo_TAMINANGO_3_M_10
# R_peso_maximo_TAMINANGO_3_M_11
# R_peso_maximo_TAMINANGO_3_M_12
# R_peso_maximo_TAMINANGO_4_M_8
# R_peso_maximo_TAMINANGO_4_M_9
# R_peso_maximo_TAMINANGO_4_M_10
# R_peso_maximo_TAMINANGO_4_M_11
# R_peso_maximo_TAMINANGO_4_M_12
# R_peso_min_campesino_POTOCO_1_M_1
# R_peso_min_campesino_POTOCO_2_M_1
# R_peso_min_campesino_POTOCO_3_M_1
# R_peso_min_campesino_POTOCO_4_M_1
# R_peso_min_campesino_POTOCO_5_M_1
# R_peso_min_campesino_POTOCO_6_M_1
# R_peso_min_campesino_POTOCO_7_M_1
# R_peso_min_campesino_POTOCO_8_M_1
# R_peso_min_campesino_POTOCO_9_M_1
# R_peso_min_campesino_ARANJUEZ_1_M_1
# R_peso_min_campesino_ARANJUEZ_4_M_1
# R_peso_min_campesino_ARANJUEZ_5_M_1
# R_peso_min_campesino_ARANJUEZ_7_M_1
# R_peso_min_campesino_NIÑA MARIA_1_M_1
# R_peso_min_campesino_NIÑA MARIA_2_M_1
# R_peso_min_campesino_NIÑA MARIA_3_M_1
# R_peso_min_campesino_MARGARITA_1_M_1
# R_peso_min_campesino_MARGARITA_1_M_2
# R_peso_min_campesino_MARGARITA_1_M_3
# R_peso_min_campesino_MARGARITA_2_M_1
# R_peso_min_campesino_MARGARITA_2_M_2
# R_peso_min_campesino_MARGARITA_2_M_3
# R_peso_min_campesino_MARGARITA_3_M_1
# R_peso_min_campesino_MARGARITA_3_M_2
# R_peso_min_campesino_MARGARITA_3_M_3
# R_peso_min_campesino_MARGARITA_4_M_1
# R_peso_min_campesino_MARGARITA_4_M_2
# R_peso_min_campesino_MARGARITA_4_M_3
# R_peso_min_campesino_TAMINANGO_1_M_1
# R_peso_min_campesino_TAMINANGO_1_M_2
# R_peso_min_campesino_TAMINANGO_2_M_1
# R_peso_min_campesino_TAMINANGO_2_M_2
# R_peso_min_campesino_TAMINANGO_3_M_1
# R_peso_min_campesino_TAMINANGO_3_M_2
# R_peso_min_campesino_TAMINANGO_4_M_1
# R_peso_min_campesino_TAMINANGO_4_M_2
# R_peso_min_campesino_SAN BUENO_3_M_1
# R_peso_min_campesino_SAN BUENO_3_M_2
# R_peso_min_campesino_SAN BUENO_3_M_3
# R_peso_min_campesino_SAN BUENO_3_M_4
# R_peso_min_campesino_SAN BUENO_3_M_5
# R_peso_min_campesino_SAN BUENO_3_M_6
# R_peso_min_campesino_SAN BUENO_4_M_1
# R_peso_min_campesino_SAN BUENO_4_M_2
# R_peso_min_campesino_SAN BUENO_4_M_3
# R_peso_min_campesino_SAN BUENO_4_M_4
# R_peso_min_campesino_SAN BUENO_4_M_5
# R_peso_min_campesino_SAN BUENO_4_M_6
# R_peso_min_campesino_SAN BUENO_5_M_1
# R_peso_min_campesino_SAN BUENO_5_M_2
# R_peso_min_campesino_SAN BUENO_5_M_3
# R_peso_min_campesino_SAN BUENO_5_M_4
# R_peso_min_campesino_SAN BUENO_5_M_5
# R_peso_min_campesino_SAN BUENO_5_M_6
# R_peso_min_campesino_SAN BUENO_6_M_1
# R_peso_min_campesino_SAN BUENO_6_M_2
# R_peso_min_campesino_SAN BUENO_6_M_3
# R_peso_min_campesino_SAN BUENO_6_M_4
# R_peso_min_campesino_SAN BUENO_6_M_5
# R_peso_min_campesino_SAN BUENO_6_M_6
# R_peso_min_campesino_SAN BUENO_7_M_1
# R_peso_min_campesino_SAN BUENO_7_M_2
# R_peso_min_campesino_SAN BUENO_7_M_3
# R_peso_min_campesino_SAN BUENO_7_M_4
# R_peso_min_campesino_SAN BUENO_7_M_5
# R_peso_min_campesino_SAN BUENO_7_M_6
# R_peso_min_campesino_SANTA MONICA_1_M_1
# R_peso_min_campesino_SANTA MONICA_1_M_2
# R_peso_min_campesino_SANTA MONICA_1_M_3
# R_peso_min_campesino_SANTA MONICA_1_M_4
# R_peso_min_campesino_SANTA MONICA_1_M_5
# R_peso_min_campesino_SANTA MONICA_1_M_6
# R_peso_min_campesino_SANTA MONICA_2_M_1
# R_peso_min_campesino_SANTA MONICA_2_M_2
# R_peso_min_campesino_SANTA MONICA_2_M_3
# R_peso_min_campesino_SANTA MONICA_2_M_4
# R_peso_min_campesino_SANTA MONICA_2_M_5
# R_peso_min_campesino_SANTA MONICA_2_M_6
# R_peso_min_campesino_SANTA MONICA_3_M_1
# R_peso_min_campesino_SANTA MONICA_3_M_2
# R_peso_min_campesino_SANTA MONICA_3_M_3
# R_peso_min_campesino_SANTA MONICA_3_M_4
# R_peso_min_campesino_SANTA MONICA_3_M_5
# R_peso_min_campesino_SANTA MONICA_3_M_6
# R_peso_min_campesino_SANTA MONICA_4_M_1
# R_peso_min_campesino_SANTA MONICA_4_M_2
# R_peso_min_campesino_SANTA MONICA_4_M_3
# R_peso_min_campesino_SANTA MONICA_4_M_4
# R_peso_min_campesino_SANTA MONICA_4_M_5
# R_peso_min_campesino_SANTA MONICA_4_M_6
# R_peso_min_campesino_SANTA MONICA_5_M_1
# R_peso_min_campesino_SANTA MONICA_5_M_2
# R_peso_min_campesino_SANTA MONICA_5_M_3
# R_peso_min_campesino_SANTA MONICA_5_M_4
# R_peso_min_campesino_SANTA MONICA_5_M_5
# R_peso_min_campesino_SANTA MONICA_5_M_6
# R_peso_min_campesino_SANTA MONICA_6_M_1
# R_peso_min_campesino_SANTA MONICA_6_M_2
# R_peso_min_campesino_SANTA MONICA_6_M_3
# R_peso_min_campesino_SANTA MONICA_6_M_4
# R_peso_min_campesino_SANTA MONICA_6_M_5
# R_peso_min_campesino_SANTA MONICA_6_M_6
# R_peso_min_campesino_SANTA MONICA_7_M_1
# R_peso_min_campesino_SANTA MONICA_7_M_2
# R_peso_min_campesino_SANTA MONICA_7_M_3
# R_peso_min_campesino_SANTA MONICA_7_M_4
# R_peso_min_campesino_SANTA MONICA_7_M_5
# R_peso_min_campesino_SANTA MONICA_7_M_6
# R_peso_min_campesino_SANTA MONICA_8_M_1
# R_peso_min_campesino_SANTA MONICA_8_M_2
# R_peso_min_campesino_SANTA MONICA_8_M_3
# R_peso_min_campesino_SANTA MONICA_8_M_4
# R_peso_min_campesino_SANTA MONICA_8_M_5
# R_peso_min_campesino_SANTA MONICA_8_M_6
# R_peso_min_campesino_SANTA MONICA_9_M_1
# R_peso_min_campesino_SANTA MONICA_9_M_2
# R_peso_min_campesino_SANTA MONICA_9_M_3
# R_peso_min_campesino_SANTA MONICA_9_M_4
# R_peso_min_campesino_SANTA MONICA_9_M_5
# R_peso_min_campesino_SANTA MONICA_9_M_6
# R_peso_min_campesino_SANTA MONICA_10_M_1
# R_peso_min_campesino_SANTA MONICA_10_M_2
# R_peso_min_campesino_SANTA MONICA_10_M_3
# R_peso_min_campesino_SANTA MONICA_10_M_4
# R_peso_min_campesino_SANTA MONICA_10_M_5
# R_peso_min_campesino_SANTA MONICA_10_M_6
# R_peso_min_campesino_SANTA MONICA_11_M_1
# R_peso_min_campesino_SANTA MONICA_11_M_2
# R_peso_min_campesino_SANTA MONICA_11_M_3
# R_peso_min_campesino_SANTA MONICA_11_M_4
# R_peso_min_campesino_SANTA MONICA_11_M_5
# R_peso_min_campesino_SANTA MONICA_11_M_6
# R_peso_min_campesino_VALLE DE ORO_1_M_1
# R_peso_min_campesino_VALLE DE ORO_1_M_2
# R_peso_min_campesino_VALLE DE ORO_1_M_3
# R_peso_min_campesino_VALLE DE ORO_1_M_4
# R_peso_min_campesino_VALLE DE ORO_1_M_5
# R_peso_min_campesino_VALLE DE ORO_1_M_6
# R_peso_min_campesino_VALLE DE ORO_2_M_1
# R_peso_min_campesino_VALLE DE ORO_2_M_2
# R_peso_min_campesino_VALLE DE ORO_2_M_3
# R_peso_min_campesino_VALLE DE ORO_2_M_4
# R_peso_min_campesino_VALLE DE ORO_2_M_5
# R_peso_min_campesino_VALLE DE ORO_2_M_6
# R_peso_min_campesino_VALLE DE ORO_3_M_1
# R_peso_min_campesino_VALLE DE ORO_3_M_2
# R_peso_min_campesino_VALLE DE ORO_3_M_3
# R_peso_min_campesino_VALLE DE ORO_3_M_4
# R_peso_min_campesino_VALLE DE ORO_3_M_5
# R_peso_min_campesino_VALLE DE ORO_3_M_6
# R_peso_min_campesino_VALLE DE ORO_4_M_1
# R_peso_min_campesino_VALLE DE ORO_4_M_2
# R_peso_min_campesino_VALLE DE ORO_4_M_3
# R_peso_min_campesino_VALLE DE ORO_4_M_4
# R_peso_min_campesino_VALLE DE ORO_4_M_5
# R_peso_min_campesino_VALLE DE ORO_4_M_6
# R_peso_min_campesino_VALLE DE ORO_5_M_1
# R_peso_min_campesino_VALLE DE ORO_5_M_2
# R_peso_min_campesino_VALLE DE ORO_5_M_3
# R_peso_min_campesino_VALLE DE ORO_5_M_4
# R_peso_min_campesino_VALLE DE ORO_5_M_5
# R_peso_min_campesino_VALLE DE ORO_5_M_6
# R_peso_min_campesino_VALLE DE ORO_6_M_1
# R_peso_min_campesino_VALLE DE ORO_6_M_2
# R_peso_min_campesino_VALLE DE ORO_6_M_3
# R_peso_min_campesino_VALLE DE ORO_6_M_4
# R_peso_min_campesino_VALLE DE ORO_6_M_5
# R_peso_min_campesino_VALLE DE ORO_6_M_6
# R_peso_min_campesino_VALLE DE ORO_7_M_1
# R_peso_min_campesino_VALLE DE ORO_7_M_2
# R_peso_min_campesino_VALLE DE ORO_7_M_3
# R_peso_min_campesino_VALLE DE ORO_7_M_4
# R_peso_min_campesino_VALLE DE ORO_7_M_5
# R_peso_min_campesino_VALLE DE ORO_7_M_6
# R_peso_min_campesino_VALLE DE ORO_8_M_1
# R_peso_min_campesino_VALLE DE ORO_8_M_2
# R_peso_min_campesino_VALLE DE ORO_8_M_3
# R_peso_min_campesino_VALLE DE ORO_8_M_4
# R_peso_min_campesino_VALLE DE ORO_8_M_5
# R_peso_min_campesino_VALLE DE ORO_8_M_6
# R_peso_min_campesino_VALLE DE ORO_9_M_1
# R_peso_min_campesino_VALLE DE ORO_9_M_2
# R_peso_min_campesino_VALLE DE ORO_9_M_3
# R_peso_min_campesino_VALLE DE ORO_9_M_4
# R_peso_min_campesino_VALLE DE ORO_9_M_5
# R_peso_min_campesino_VALLE DE ORO_9_M_6
# R_peso_min_campesino_VALLE DE ORO_10_M_1
# R_peso_min_campesino_VALLE DE ORO_10_M_2
# R_peso_min_campesino_VALLE DE ORO_10_M_3
# R_peso_min_campesino_VALLE DE ORO_10_M_4
# R_peso_min_campesino_VALLE DE ORO_10_M_5
# R_peso_min_campesino_VALLE DE ORO_10_M_6
# R_peso_min_campesino_LA JUANA_4_M_1
# R_peso_min_campesino_LA JUANA_4_M_2
# R_peso_min_campesino_LA JUANA_4_M_3
# R_peso_min_campesino_LA JUANA_4_M_4
# R_peso_min_campesino_LA JUANA_4_M_5
# R_peso_min_campesino_LA JUANA_4_M_6
# R_peso_min_campesino_LA JUANA_5_M_1
# R_peso_min_campesino_LA JUANA_5_M_2
# R_peso_min_campesino_LA JUANA_5_M_3
# R_peso_min_campesino_LA JUANA_5_M_4
# R_peso_min_campesino_LA JUANA_5_M_5
# R_peso_min_campesino_LA JUANA_5_M_6
# R_peso_min_campesino_RECREO_1_M_1
# R_peso_min_campesino_RECREO_1_M_2
# R_peso_min_campesino_RECREO_1_M_3
# R_peso_min_campesino_RECREO_1_M_4
# R_peso_min_campesino_RECREO_1_M_5
# R_peso_min_campesino_RECREO_1_M_6
# R_peso_min_campesino_RECREO_2_M_1
# R_peso_min_campesino_RECREO_2_M_2
# R_peso_min_campesino_RECREO_2_M_3
# R_peso_min_campesino_RECREO_2_M_4
# R_peso_min_campesino_RECREO_2_M_5
# R_peso_min_campesino_RECREO_2_M_6
# R_peso_min_campesino_RECREO_3_M_1
# R_peso_min_campesino_RECREO_3_M_2
# R_peso_min_campesino_RECREO_3_M_3
# R_peso_min_campesino_RECREO_3_M_4
# R_peso_min_campesino_RECREO_3_M_5
# R_peso_min_campesino_RECREO_3_M_6
# R_peso_min_campesino_RECREO_4_M_1
# R_peso_min_campesino_RECREO_4_M_2
# R_peso_min_campesino_RECREO_4_M_3
# R_peso_min_campesino_RECREO_4_M_4
# R_peso_min_campesino_RECREO_4_M_5
# R_peso_min_campesino_RECREO_4_M_6
# R_peso_min_campesino_ALBORADA_4_M_1
# R_peso_min_campesino_ALBORADA_4_M_2
# R_peso_min_campesino_ALBORADA_4_M_3
# R_peso_min_campesino_ALBORADA_4_M_4
# R_peso_min_campesino_ALBORADA_4_M_5
# R_peso_min_campesino_ALBORADA_4_M_6
# R_peso_min_campesino_ALBORADA_4_M_7
# R_peso_min_campesino_ALBORADA_4_M_8
# R_peso_min_campesino_ALBORADA_4_M_9
# R_peso_min_campesino_ALBORADA_4_M_10
# R_peso_min_campesino_EL EDEN_8_M_1
# R_peso_min_campesino_EL EDEN_8_M_2
# R_peso_min_campesino_EL EDEN_8_M_3
# R_peso_min_campesino_EL EDEN_8_M_4
# R_peso_min_campesino_EL EDEN_8_M_5
# R_peso_min_campesino_EL EDEN_8_M_6
# R_peso_min_campesino_EL EDEN_8_M_7
# R_peso_min_campesino_EL EDEN_9_M_1
# R_peso_min_campesino_EL EDEN_9_M_2
# R_peso_min_campesino_EL EDEN_9_M_3
# R_peso_min_campesino_EL EDEN_9_M_4
# R_peso_min_campesino_EL EDEN_9_M_5
# R_peso_min_campesino_EL EDEN_9_M_6
# R_peso_min_campesino_EL EDEN_9_M_7
# R_peso_min_campesino_EL EDEN_10_M_1
# R_peso_min_campesino_EL EDEN_10_M_2
# R_peso_min_campesino_EL EDEN_10_M_3
# R_peso_min_campesino_EL EDEN_10_M_4
# R_peso_min_campesino_EL EDEN_10_M_5
# R_peso_min_campesino_EL EDEN_10_M_6
# R_peso_min_campesino_EL EDEN_10_M_7
# R_peso_min_campesino_EL EDEN_11_M_1
# R_peso_min_campesino_EL EDEN_11_M_2
# R_peso_min_campesino_EL EDEN_11_M_3
# R_peso_min_campesino_EL EDEN_11_M_4
# R_peso_min_campesino_EL EDEN_11_M_5
# R_peso_min_campesino_EL EDEN_11_M_6
# R_peso_min_campesino_EL EDEN_11_M_7
# R_peso_min_campesino_LA JUANA_2_M_1
# R_peso_min_campesino_LA JUANA_2_M_2
# R_peso_min_campesino_LA JUANA_2_M_3
# R_peso_min_campesino_LA JUANA_2_M_4
# R_peso_min_campesino_LA JUANA_2_M_5
# R_peso_min_campesino_LA JUANA_2_M_6
# R_peso_min_campesino_LA JUANA_2_M_7
# R_peso_min_campesino_LA JUANA_2_M_8
# R_peso_min_campesino_LA JUANA_3_M_1
# R_peso_min_campesino_LA JUANA_3_M_2
# R_peso_min_campesino_LA JUANA_3_M_3
# R_peso_min_campesino_LA JUANA_3_M_4
# R_peso_min_campesino_LA JUANA_3_M_5
# R_peso_min_campesino_LA JUANA_3_M_6
# R_peso_min_campesino_LA JUANA_3_M_7
# R_peso_min_campesino_LA JUANA_3_M_8
# R_peso_min_campesino_LA GUAQUITA_2_M_1
# R_peso_min_campesino_LA GUAQUITA_2_M_2
# R_peso_min_campesino_LA GUAQUITA_2_M_3
# R_peso_min_campesino_LA GUAQUITA_2_M_4
# R_peso_min_campesino_LA GUAQUITA_2_M_5
# R_peso_min_campesino_LA GUAQUITA_2_M_6
# R_peso_min_campesino_LA GUAQUITA_2_M_7
# R_peso_min_campesino_LA GUAQUITA_2_M_8
# R_peso_min_campesino_LA GUAQUITA_2_M_9
# R_peso_min_campesino_LA GUAQUITA_2_M_10
# R_peso_min_campesino_LA GUAQUITA_2_M_11
# R_peso_min_campesino_LA GUAQUITA_2_M_12
# R_peso_min_campesino_MONTE OSCURO_5_M_1
# R_peso_min_campesino_MONTE OSCURO_5_M_2
# R_peso_min_campesino_MONTE OSCURO_5_M_3
# R_peso_min_campesino_MONTE OSCURO_5_M_4
# R_peso_min_campesino_MONTE OSCURO_5_M_5
# R_peso_min_campesino_MONTE OSCURO_5_M_6
# R_peso_min_campesino_MONTE OSCURO_5_M_7
# R_peso_min_campesino_MONTE OSCURO_5_M_8
# R_peso_min_campesino_MONTE OSCURO_6_M_1
# R_peso_min_campesino_MONTE OSCURO_6_M_2
# R_peso_min_campesino_MONTE OSCURO_6_M_3
# R_peso_min_campesino_MONTE OSCURO_6_M_4
# R_peso_min_campesino_MONTE OSCURO_6_M_5
# R_peso_min_campesino_MONTE OSCURO_6_M_6
# R_peso_min_campesino_MONTE OSCURO_6_M_7
# R_peso_min_campesino_MONTE OSCURO_6_M_8
# R_peso_min_campesino_MONTE OSCURO_1_M_1
# R_peso_min_campesino_MONTE OSCURO_1_M_2
# R_peso_min_campesino_MONTE OSCURO_1_M_3
# R_peso_min_campesino_MONTE OSCURO_1_M_4
# R_peso_min_campesino_MONTE OSCURO_1_M_5
# R_peso_min_campesino_MONTE OSCURO_1_M_6
# R_peso_min_campesino_MONTE OSCURO_1_M_7
# R_peso_min_campesino_MONTE OSCURO_1_M_8
# R_peso_min_campesino_MONTE OSCURO_1_M_9
# R_peso_min_campesino_MONTE OSCURO_2_M_1
# R_peso_min_campesino_MONTE OSCURO_2_M_2
# R_peso_min_campesino_MONTE OSCURO_2_M_3
# R_peso_min_campesino_MONTE OSCURO_2_M_4
# R_peso_min_campesino_MONTE OSCURO_2_M_5
# R_peso_min_campesino_MONTE OSCURO_2_M_6
# R_peso_min_campesino_MONTE OSCURO_2_M_7
# R_peso_min_campesino_MONTE OSCURO_2_M_8
# R_peso_min_campesino_MONTE OSCURO_2_M_9
# R_peso_min_campesino_MONTE OSCURO_3_M_1
# R_peso_min_campesino_MONTE OSCURO_3_M_2
# R_peso_min_campesino_MONTE OSCURO_3_M_3
# R_peso_min_campesino_MONTE OSCURO_3_M_4
# R_peso_min_campesino_MONTE OSCURO_3_M_5
# R_peso_min_campesino_MONTE OSCURO_3_M_6
# R_peso_min_campesino_MONTE OSCURO_3_M_7
# R_peso_min_campesino_MONTE OSCURO_3_M_8
# R_peso_min_campesino_MONTE OSCURO_3_M_9
# R_peso_min_campesino_MONTE OSCURO_4_M_1
# R_peso_min_campesino_MONTE OSCURO_4_M_2
# R_peso_min_campesino_MONTE OSCURO_4_M_3
# R_peso_min_campesino_MONTE OSCURO_4_M_4
# R_peso_min_campesino_MONTE OSCURO_4_M_5
# R_peso_min_campesino_MONTE OSCURO_4_M_6
# R_peso_min_campesino_MONTE OSCURO_4_M_7
# R_peso_min_campesino_MONTE OSCURO_4_M_8
# R_peso_min_campesino_MONTE OSCURO_4_M_9
# R_peso_min_campesino_ABISINIA_1_M_1
# R_peso_min_campesino_ABISINIA_1_M_2
# R_peso_min_campesino_ABISINIA_1_M_3
# R_peso_min_campesino_ABISINIA_1_M_4
# R_peso_min_campesino_ABISINIA_1_M_5
# R_peso_min_campesino_ABISINIA_1_M_6
# R_peso_min_campesino_ABISINIA_1_M_7
# R_peso_min_campesino_ABISINIA_1_M_8
# R_peso_min_campesino_ABISINIA_1_M_9
# R_peso_min_campesino_ABISINIA_1_M_10
# R_peso_min_campesino_ABISINIA_1_M_11
# R_peso_min_campesino_ABISINIA_2_M_1
# R_peso_min_campesino_ABISINIA_2_M_2
# R_peso_min_campesino_ABISINIA_2_M_3
# R_peso_min_campesino_ABISINIA_2_M_4
# R_peso_min_campesino_ABISINIA_2_M_5
# R_peso_min_campesino_ABISINIA_2_M_6
# R_peso_min_campesino_ABISINIA_2_M_7
# R_peso_min_campesino_ABISINIA_2_M_8
# R_peso_min_campesino_ABISINIA_2_M_9
# R_peso_min_campesino_ABISINIA_2_M_10
# R_peso_min_campesino_ABISINIA_2_M_11
# R_peso_min_campesino_LA GUAQUITA_4_M_1
# R_peso_min_campesino_LA GUAQUITA_4_M_2
# R_peso_min_campesino_LA GUAQUITA_4_M_3
# R_peso_min_campesino_LA GUAQUITA_4_M_4
# R_peso_min_campesino_LA GUAQUITA_4_M_5
# R_peso_min_campesino_LA GUAQUITA_4_M_6
# R_peso_min_campesino_LA GUAQUITA_4_M_7
# R_peso_min_campesino_LA GUAQUITA_4_M_8
# R_peso_min_campesino_LA GUAQUITA_4_M_9
# R_peso_min_campesino_LA GUAQUITA_4_M_10
# R_peso_min_campesino_LA GUAQUITA_4_M_11
# R_peso_min_campesino_LA GUAQUITA_4_M_12
# R_peso_min_campesino_LA GUAQUITA_5_M_1
# R_peso_min_campesino_LA GUAQUITA_5_M_2
# R_peso_min_campesino_LA GUAQUITA_5_M_3
# R_peso_min_campesino_LA GUAQUITA_5_M_4
# R_peso_min_campesino_LA GUAQUITA_5_M_5
# R_peso_min_campesino_LA GUAQUITA_5_M_6
# R_peso_min_campesino_LA GUAQUITA_5_M_7
# R_peso_min_campesino_LA GUAQUITA_5_M_8
# R_peso_min_campesino_LA GUAQUITA_5_M_9
# R_peso_min_campesino_LA GUAQUITA_5_M_10
# R_peso_min_campesino_LA GUAQUITA_5_M_11
# R_peso_min_campesino_LA GUAQUITA_5_M_12
# R_peso_min_campesino_LA REINA_1_M_1
# R_peso_min_campesino_LA REINA_1_M_2
# R_peso_min_campesino_LA REINA_1_M_3
# R_peso_min_campesino_LA REINA_1_M_4
# R_peso_min_campesino_LA REINA_1_M_5
# R_peso_min_campesino_LA REINA_1_M_6
# R_peso_min_campesino_LA REINA_1_M_7
# R_peso_min_campesino_LA REINA_1_M_8
# R_peso_min_campesino_LA REINA_1_M_9
# R_peso_min_campesino_LA REINA_1_M_10
# R_peso_min_campesino_LA REINA_1_M_11
# R_peso_min_campesino_LA REINA_1_M_12
# R_peso_min_campesino_LA REINA_1_H_1
# R_peso_min_campesino_LA REINA_1_H_2
# R_peso_min_campesino_LA REINA_1_H_3
# R_peso_min_campesino_LA REINA_1_H_4
# R_peso_min_campesino_LA REINA_1_H_5
# R_peso_min_campesino_LA REINA_1_H_6
# R_peso_min_campesino_LA REINA_1_H_7
# R_peso_min_campesino_LA REINA_1_H_8
# R_peso_min_campesino_LA REINA_1_H_9
# R_peso_min_campesino_LA REINA_1_H_10
# R_peso_min_campesino_LA REINA_1_H_11
# R_peso_min_campesino_LA REINA_1_H_12
# R_peso_min_campesino_ABISINIA_5_M_1
# R_peso_min_campesino_ABISINIA_5_M_2
# R_peso_min_campesino_ABISINIA_5_M_3
# R_peso_min_campesino_ABISINIA_5_M_4
# R_peso_min_campesino_ABISINIA_5_M_5
# R_peso_min_campesino_ABISINIA_5_M_6
# R_peso_min_campesino_ABISINIA_5_M_7
# R_peso_min_campesino_ABISINIA_5_M_8
# R_peso_min_campesino_ABISINIA_5_M_9
# R_peso_min_campesino_ABISINIA_5_M_10
# R_peso_min_campesino_ABISINIA_5_M_11
# R_peso_min_campesino_ABISINIA_5_M_12
# R_peso_min_campesino_ABISINIA_6_M_1
# R_peso_min_campesino_ABISINIA_6_M_2
# R_peso_min_campesino_ABISINIA_6_M_3
# R_peso_min_campesino_ABISINIA_6_M_4
# R_peso_min_campesino_ABISINIA_6_M_5
# R_peso_min_campesino_ABISINIA_6_M_6
# R_peso_min_campesino_ABISINIA_6_M_7
# R_peso_min_campesino_ABISINIA_6_M_8
# R_peso_min_campesino_ABISINIA_6_M_9
# R_peso_min_campesino_ABISINIA_6_M_10
# R_peso_min_campesino_ABISINIA_6_M_11
# R_peso_min_campesino_ABISINIA_6_M_12
# R_peso_min_campesino_ABISINIA_7_M_1
# R_peso_min_campesino_ABISINIA_7_M_2
# R_peso_min_campesino_ABISINIA_7_M_3
# R_peso_min_campesino_ABISINIA_7_M_4
# R_peso_min_campesino_ABISINIA_7_M_5
# R_peso_min_campesino_ABISINIA_7_M_6
# R_peso_min_campesino_ABISINIA_7_M_7
# R_peso_min_campesino_ABISINIA_7_M_8
# R_peso_min_campesino_ABISINIA_7_M_9
# R_peso_min_campesino_ABISINIA_7_M_10
# R_peso_min_campesino_ABISINIA_7_M_11
# R_peso_min_campesino_ABISINIA_7_M_12
# R_peso_min_campesino_ABISINIA_8_M_1
# R_peso_min_campesino_ABISINIA_8_M_2
# R_peso_min_campesino_ABISINIA_8_M_3
# R_peso_min_campesino_ABISINIA_8_M_4
# R_peso_min_campesino_ABISINIA_8_M_5
# R_peso_min_campesino_ABISINIA_8_M_6
# R_peso_min_campesino_ABISINIA_8_M_7
# R_peso_min_campesino_ABISINIA_8_M_8
# R_peso_min_campesino_ABISINIA_8_M_9
# R_peso_min_campesino_ABISINIA_8_M_10
# R_peso_min_campesino_ABISINIA_8_M_11
# R_peso_min_campesino_ABISINIA_8_M_12
# R_peso_min_campesino_ABISINIA_9_M_1
# R_peso_min_campesino_ABISINIA_9_M_2
# R_peso_min_campesino_ABISINIA_9_M_3
# R_peso_min_campesino_ABISINIA_9_M_4
# R_peso_min_campesino_ABISINIA_9_M_5
# R_peso_min_campesino_ABISINIA_9_M_6
# R_peso_min_campesino_ABISINIA_9_M_7
# R_peso_min_campesino_ABISINIA_9_M_8
# R_peso_min_campesino_ABISINIA_9_M_9
# R_peso_min_campesino_ABISINIA_9_M_10
# R_peso_min_campesino_ABISINIA_9_M_11
# R_peso_min_campesino_ABISINIA_9_M_12
# R_peso_min_campesino_ABISINIA_10_M_1
# R_peso_min_campesino_ABISINIA_10_M_2
# R_peso_min_campesino_ABISINIA_10_M_3
# R_peso_min_campesino_ABISINIA_10_M_4
# R_peso_min_campesino_ABISINIA_10_M_5
# R_peso_min_campesino_ABISINIA_10_M_6
# R_peso_min_campesino_ABISINIA_10_M_7
# R_peso_min_campesino_ABISINIA_10_M_8
# R_peso_min_campesino_ABISINIA_10_M_9
# R_peso_min_campesino_ABISINIA_10_M_10
# R_peso_min_campesino_ABISINIA_10_M_11
# R_peso_min_campesino_ABISINIA_10_M_12
# R_peso_min_campesino_EL ENCANTO_7_M_1
# R_peso_min_campesino_EL ENCANTO_7_M_2
# R_peso_min_campesino_EL ENCANTO_7_M_3
# R_peso_min_campesino_EL ENCANTO_7_M_4
# R_peso_min_campesino_EL ENCANTO_7_M_5
# R_peso_min_campesino_EL ENCANTO_7_M_6
# R_peso_min_campesino_EL ENCANTO_7_M_7
# R_peso_min_campesino_EL ENCANTO_7_M_8
# R_peso_min_campesino_EL ENCANTO_7_M_9
# R_peso_min_campesino_EL ENCANTO_7_M_10
# R_peso_min_campesino_EL ENCANTO_7_M_11
# R_peso_min_campesino_EL ENCANTO_7_M_12
# R_peso_min_campesino_EL ENCANTO_8_M_1
# R_peso_min_campesino_EL ENCANTO_8_M_2
# R_peso_min_campesino_EL ENCANTO_8_M_3
# R_peso_min_campesino_EL ENCANTO_8_M_4
# R_peso_min_campesino_EL ENCANTO_8_M_5
# R_peso_min_campesino_EL ENCANTO_8_M_6
# R_peso_min_campesino_EL ENCANTO_8_M_7
# R_peso_min_campesino_EL ENCANTO_8_M_8
# R_peso_min_campesino_EL ENCANTO_8_M_9
# R_peso_min_campesino_EL ENCANTO_8_M_10
# R_peso_min_campesino_EL ENCANTO_8_M_11
# R_peso_min_campesino_EL ENCANTO_8_M_12
# R_peso_min_campesino_EL ENCANTO_9_M_1
# R_peso_min_campesino_EL ENCANTO_9_M_2
# R_peso_min_campesino_EL ENCANTO_9_M_3
# R_peso_min_campesino_EL ENCANTO_9_M_4
# R_peso_min_campesino_EL ENCANTO_9_M_5
# R_peso_min_campesino_EL ENCANTO_9_M_6
# R_peso_min_campesino_EL ENCANTO_9_M_7
# R_peso_min_campesino_EL ENCANTO_9_M_8
# R_peso_min_campesino_EL ENCANTO_9_M_9
# R_peso_min_campesino_EL ENCANTO_9_M_10
# R_peso_min_campesino_EL ENCANTO_9_M_11
# R_peso_min_campesino_EL ENCANTO_9_M_12
# R_peso_min_campesino_EL ENCANTO_17_M_1
# R_peso_min_campesino_EL ENCANTO_17_M_2
# R_peso_min_campesino_EL ENCANTO_17_M_3
# R_peso_min_campesino_EL ENCANTO_17_M_4
# R_peso_min_campesino_EL ENCANTO_17_M_5
# R_peso_min_campesino_EL ENCANTO_17_M_6
# R_peso_min_campesino_EL ENCANTO_17_M_7
# R_peso_min_campesino_EL ENCANTO_17_M_8
# R_peso_min_campesino_EL ENCANTO_17_M_9
# R_peso_min_campesino_EL ENCANTO_17_M_10
# R_peso_min_campesino_EL ENCANTO_17_M_11
# R_peso_min_campesino_EL ENCANTO_17_M_12
# R_peso_min_campesino_EL ENCANTO_18_M_1
# R_peso_min_campesino_EL ENCANTO_18_M_2
# R_peso_min_campesino_EL ENCANTO_18_M_3
# R_peso_min_campesino_EL ENCANTO_18_M_4
# R_peso_min_campesino_EL ENCANTO_18_M_5
# R_peso_min_campesino_EL ENCANTO_18_M_6
# R_peso_min_campesino_EL ENCANTO_18_M_7
# R_peso_min_campesino_EL ENCANTO_18_M_8
# R_peso_min_campesino_EL ENCANTO_18_M_9
# R_peso_min_campesino_EL ENCANTO_18_M_10
# R_peso_min_campesino_EL ENCANTO_18_M_11
# R_peso_min_campesino_EL ENCANTO_18_M_12
# R_peso_min_campesino_LA CABAÑITA_4_M_1
# R_peso_min_campesino_LA CABAÑITA_4_M_2
# R_peso_min_campesino_LA CABAÑITA_4_M_3
# R_peso_min_campesino_LA CABAÑITA_4_M_4
# R_peso_min_campesino_LA CABAÑITA_4_M_5
# R_peso_min_campesino_LA CABAÑITA_4_M_6
# R_peso_min_campesino_LA CABAÑITA_4_M_7
# R_peso_min_campesino_LA CABAÑITA_4_M_8
# R_peso_min_campesino_LA CABAÑITA_4_M_9
# R_peso_min_campesino_LA CABAÑITA_4_M_10
# R_peso_min_campesino_LA CABAÑITA_4_M_11
# R_peso_min_campesino_LA CABAÑITA_4_M_12
# R_peso_min_campesino_LA CABAÑITA_6_M_1
# R_peso_min_campesino_LA CABAÑITA_6_M_2
# R_peso_min_campesino_LA CABAÑITA_6_M_3
# R_peso_min_campesino_LA CABAÑITA_6_M_4
# R_peso_min_campesino_LA CABAÑITA_6_M_5
# R_peso_min_campesino_LA CABAÑITA_6_M_6
# R_peso_min_campesino_LA CABAÑITA_6_M_7
# R_peso_min_campesino_LA CABAÑITA_6_M_8
# R_peso_min_campesino_LA CABAÑITA_6_M_9
# R_peso_min_campesino_LA CABAÑITA_6_M_10
# R_peso_min_campesino_LA CABAÑITA_6_M_11
# R_peso_min_campesino_LA CABAÑITA_6_M_12
# R_peso_min_campesino_LA CABAÑITA_7_M_1
# R_peso_min_campesino_LA CABAÑITA_7_M_2
# R_peso_min_campesino_LA CABAÑITA_7_M_3
# R_peso_min_campesino_LA CABAÑITA_7_M_4
# R_peso_min_campesino_LA CABAÑITA_7_M_5
# R_peso_min_campesino_LA CABAÑITA_7_M_6
# R_peso_min_campesino_LA CABAÑITA_7_M_7
# R_peso_min_campesino_LA CABAÑITA_7_M_8
# R_peso_min_campesino_LA CABAÑITA_7_M_9
# R_peso_min_campesino_LA CABAÑITA_7_M_10
# R_peso_min_campesino_LA CABAÑITA_7_M_11
# R_peso_min_campesino_LA CABAÑITA_7_M_12
# R_peso_min_campesino_EL ENCANTO_6_M_1
# R_peso_min_campesino_EL ENCANTO_6_M_2
# R_peso_min_campesino_EL ENCANTO_6_M_3
# R_peso_min_campesino_EL ENCANTO_6_M_4
# R_peso_min_campesino_EL ENCANTO_6_M_5
# R_peso_min_campesino_EL ENCANTO_6_M_6
# R_peso_min_campesino_EL ENCANTO_6_M_7
# R_peso_min_campesino_EL ENCANTO_6_M_8
# R_peso_min_campesino_EL ENCANTO_6_M_9
# R_peso_min_campesino_EL ENCANTO_6_M_10
# R_peso_min_campesino_EL ENCANTO_6_M_11
# R_peso_min_campesino_EL ENCANTO_6_M_12
# R_peso_min_campesino_EL ENCANTO_10_M_1
# R_peso_min_campesino_EL ENCANTO_10_M_2
# R_peso_min_campesino_EL ENCANTO_10_M_3
# R_peso_min_campesino_EL ENCANTO_10_M_4
# R_peso_min_campesino_EL ENCANTO_10_M_5
# R_peso_min_campesino_EL ENCANTO_10_M_6
# R_peso_min_campesino_EL ENCANTO_10_M_7
# R_peso_min_campesino_EL ENCANTO_10_M_8
# R_peso_min_campesino_EL ENCANTO_10_M_9
# R_peso_min_campesino_EL ENCANTO_10_M_10
# R_peso_min_campesino_EL ENCANTO_10_M_11
# R_peso_min_campesino_EL ENCANTO_10_M_12
# R_peso_min_campesino_EL ENCANTO_11_M_1
# R_peso_min_campesino_EL ENCANTO_11_M_2
# R_peso_min_campesino_EL ENCANTO_11_M_3
# R_peso_min_campesino_EL ENCANTO_11_M_4
# R_peso_min_campesino_EL ENCANTO_11_M_5
# R_peso_min_campesino_EL ENCANTO_11_M_6
# R_peso_min_campesino_EL ENCANTO_11_M_7
# R_peso_min_campesino_EL ENCANTO_11_M_8
# R_peso_min_campesino_EL ENCANTO_11_M_9
# R_peso_min_campesino_EL ENCANTO_11_M_10
# R_peso_min_campesino_EL ENCANTO_11_M_11
# R_peso_min_campesino_EL ENCANTO_11_M_12
# R_peso_min_campesino_EL ENCANTO_12_M_1
# R_peso_min_campesino_EL ENCANTO_12_M_2
# R_peso_min_campesino_EL ENCANTO_12_M_3
# R_peso_min_campesino_EL ENCANTO_12_M_4
# R_peso_min_campesino_EL ENCANTO_12_M_5
# R_peso_min_campesino_EL ENCANTO_12_M_6
# R_peso_min_campesino_EL ENCANTO_12_M_7
# R_peso_min_campesino_EL ENCANTO_12_M_8
# R_peso_min_campesino_EL ENCANTO_12_M_9
# R_peso_min_campesino_EL ENCANTO_12_M_10
# R_peso_min_campesino_EL ENCANTO_12_M_11
# R_peso_min_campesino_EL ENCANTO_12_M_12
# R_peso_min_campesino_EL ENCANTO_13_M_1
# R_peso_min_campesino_EL ENCANTO_13_M_2
# R_peso_min_campesino_EL ENCANTO_13_M_3
# R_peso_min_campesino_EL ENCANTO_13_M_4
# R_peso_min_campesino_EL ENCANTO_13_M_5
# R_peso_min_campesino_EL ENCANTO_13_M_6
# R_peso_min_campesino_EL ENCANTO_13_M_7
# R_peso_min_campesino_EL ENCANTO_13_M_8
# R_peso_min_campesino_EL ENCANTO_13_M_9
# R_peso_min_campesino_EL ENCANTO_13_M_10
# R_peso_min_campesino_EL ENCANTO_13_M_11
# R_peso_min_campesino_EL ENCANTO_13_M_12
# R_peso_min_campesino_EL ENCANTO_14_M_1
# R_peso_min_campesino_EL ENCANTO_14_M_2
# R_peso_min_campesino_EL ENCANTO_14_M_3
# R_peso_min_campesino_EL ENCANTO_14_M_4
# R_peso_min_campesino_EL ENCANTO_14_M_5
# R_peso_min_campesino_EL ENCANTO_14_M_6
# R_peso_min_campesino_EL ENCANTO_14_M_7
# R_peso_min_campesino_EL ENCANTO_14_M_8
# R_peso_min_campesino_EL ENCANTO_14_M_9
# R_peso_min_campesino_EL ENCANTO_14_M_10
# R_peso_min_campesino_EL ENCANTO_14_M_11
# R_peso_min_campesino_EL ENCANTO_14_M_12
# R_peso_min_campesino_EL ENCANTO_15_M_1
# R_peso_min_campesino_EL ENCANTO_15_M_2
# R_peso_min_campesino_EL ENCANTO_15_M_3
# R_peso_min_campesino_EL ENCANTO_15_M_4
# R_peso_min_campesino_EL ENCANTO_15_M_5
# R_peso_min_campesino_EL ENCANTO_15_M_6
# R_peso_min_campesino_EL ENCANTO_15_M_7
# R_peso_min_campesino_EL ENCANTO_15_M_8
# R_peso_min_campesino_EL ENCANTO_15_M_9
# R_peso_min_campesino_EL ENCANTO_15_M_10
# R_peso_min_campesino_EL ENCANTO_15_M_11
# R_peso_min_campesino_EL ENCANTO_15_M_12
# R_peso_min_campesino_EL ENCANTO_16_M_1
# R_peso_min_campesino_EL ENCANTO_16_M_2
# R_peso_min_campesino_EL ENCANTO_16_M_3
# R_peso_min_campesino_EL ENCANTO_16_M_4
# R_peso_min_campesino_EL ENCANTO_16_M_5
# R_peso_min_campesino_EL ENCANTO_16_M_6
# R_peso_min_campesino_EL ENCANTO_16_M_7
# R_peso_min_campesino_EL ENCANTO_16_M_8
# R_peso_min_campesino_EL ENCANTO_16_M_9
# R_peso_min_campesino_EL ENCANTO_16_M_10
# R_peso_min_campesino_EL ENCANTO_16_M_11
# R_peso_min_campesino_EL ENCANTO_16_M_12
# R_peso_min_campesino_VILLA DEL LAGO_1_M_1
# R_peso_min_campesino_VILLA DEL LAGO_1_M_2
# R_peso_min_campesino_VILLA DEL LAGO_1_M_3
# R_peso_min_campesino_VILLA DEL LAGO_1_M_4
# R_peso_min_campesino_VILLA DEL LAGO_1_M_5
# R_peso_min_campesino_VILLA DEL LAGO_1_M_6
# R_peso_min_campesino_VILLA DEL LAGO_1_M_7
# R_peso_min_campesino_VILLA DEL LAGO_1_M_8
# R_peso_min_campesino_VILLA DEL LAGO_1_M_9
# R_peso_min_campesino_VILLA DEL LAGO_1_M_10
# R_peso_min_campesino_VILLA DEL LAGO_1_M_11
# R_peso_min_campesino_VILLA DEL LAGO_1_M_12
# R_peso_min_campesino_VILLA DEL LAGO_2_M_1
# R_peso_min_campesino_VILLA DEL LAGO_2_M_2
# R_peso_min_campesino_VILLA DEL LAGO_2_M_3
# R_peso_min_campesino_VILLA DEL LAGO_2_M_4
# R_peso_min_campesino_VILLA DEL LAGO_2_M_5
# R_peso_min_campesino_VILLA DEL LAGO_2_M_6
# R_peso_min_campesino_VILLA DEL LAGO_2_M_7
# R_peso_min_campesino_VILLA DEL LAGO_2_M_8
# R_peso_min_campesino_VILLA DEL LAGO_2_M_9
# R_peso_min_campesino_VILLA DEL LAGO_2_M_10
# R_peso_min_campesino_VILLA DEL LAGO_2_M_11
# R_peso_min_campesino_VILLA DEL LAGO_2_M_12
# R_peso_min_campesino_VILLA DEL LAGO_3_M_1
# R_peso_min_campesino_VILLA DEL LAGO_3_M_2
# R_peso_min_campesino_VILLA DEL LAGO_3_M_3
# R_peso_min_campesino_VILLA DEL LAGO_3_M_4
# R_peso_min_campesino_VILLA DEL LAGO_3_M_5
# R_peso_min_campesino_VILLA DEL LAGO_3_M_6
# R_peso_min_campesino_VILLA DEL LAGO_3_M_7
# R_peso_min_campesino_VILLA DEL LAGO_3_M_8
# R_peso_min_campesino_VILLA DEL LAGO_3_M_9
# R_peso_min_campesino_VILLA DEL LAGO_3_M_10
# R_peso_min_campesino_VILLA DEL LAGO_3_M_11
# R_peso_min_campesino_VILLA DEL LAGO_3_M_12
# R_peso_min_campesino_VILLA DEL LAGO_4_M_1
# R_peso_min_campesino_VILLA DEL LAGO_4_M_2
# R_peso_min_campesino_VILLA DEL LAGO_4_M_3
# R_peso_min_campesino_VILLA DEL LAGO_4_M_4
# R_peso_min_campesino_VILLA DEL LAGO_4_M_5
# R_peso_min_campesino_VILLA DEL LAGO_4_M_6
# R_peso_min_campesino_VILLA DEL LAGO_4_M_7
# R_peso_min_campesino_VILLA DEL LAGO_4_M_8
# R_peso_min_campesino_VILLA DEL LAGO_4_M_9
# R_peso_min_campesino_VILLA DEL LAGO_4_M_10
# R_peso_min_campesino_VILLA DEL LAGO_4_M_11
# R_peso_min_campesino_VILLA DEL LAGO_4_M_12
# R_peso_min_campesino_VILLA DEL LAGO_5_M_1
# R_peso_min_campesino_VILLA DEL LAGO_5_M_2
# R_peso_min_campesino_VILLA DEL LAGO_5_M_3
# R_peso_min_campesino_VILLA DEL LAGO_5_M_4
# R_peso_min_campesino_VILLA DEL LAGO_5_M_5
# R_peso_min_campesino_VILLA DEL LAGO_5_M_6
# R_peso_min_campesino_VILLA DEL LAGO_5_M_7
# R_peso_min_campesino_VILLA DEL LAGO_5_M_8
# R_peso_min_campesino_VILLA DEL LAGO_5_M_9
# R_peso_min_campesino_VILLA DEL LAGO_5_M_10
# R_peso_min_campesino_VILLA DEL LAGO_5_M_11
# R_peso_min_campesino_VILLA DEL LAGO_5_M_12
# R_peso_min_campesino_VILLA DEL LAGO_6_M_1
# R_peso_min_campesino_VILLA DEL LAGO_6_M_2
# R_peso_min_campesino_VILLA DEL LAGO_6_M_3
# R_peso_min_campesino_VILLA DEL LAGO_6_M_4
# R_peso_min_campesino_VILLA DEL LAGO_6_M_5
# R_peso_min_campesino_VILLA DEL LAGO_6_M_6
# R_peso_min_campesino_VILLA DEL LAGO_6_M_7
# R_peso_min_campesino_VILLA DEL LAGO_6_M_8
# R_peso_min_campesino_VILLA DEL LAGO_6_M_9
# R_peso_min_campesino_VILLA DEL LAGO_6_M_10
# R_peso_min_campesino_VILLA DEL LAGO_6_M_11
# R_peso_min_campesino_VILLA DEL LAGO_6_M_12
# R_sin_demanda_LA GUAQUITA_1_H_1
# R_sin_demanda_LA GUAQUITA_1_H_2
# R_sin_demanda_LA GUAQUITA_4_M_1
# R_sin_demanda_LA GUAQUITA_4_M_2
# R_sin_demanda_LA GUAQUITA_5_M_1
# R_sin_demanda_LA GUAQUITA_5_M_2
# R_sin_demanda_LA REINA_1_M_1
# R_sin_demanda_LA REINA_1_M_2
# R_sin_demanda_LA REINA_1_H_1
# R_sin_demanda_LA REINA_1_H_2
# R_sin_demanda_ABISINIA_5_M_1
# R_sin_demanda_ABISINIA_5_M_2
# R_sin_demanda_ABISINIA_5_M_3
# R_sin_demanda_ABISINIA_5_H_1
# R_sin_demanda_ABISINIA_5_H_2
# R_sin_demanda_ABISINIA_5_H_3
# R_sin_demanda_ABISINIA_6_M_1
# R_sin_demanda_ABISINIA_6_M_2
# R_sin_demanda_ABISINIA_6_M_3
# R_sin_demanda_ABISINIA_6_H_1
# R_sin_demanda_ABISINIA_6_H_2
# R_sin_demanda_ABISINIA_6_H_3
# R_sin_demanda_ABISINIA_7_M_1
# R_sin_demanda_ABISINIA_7_M_2
# R_sin_demanda_ABISINIA_7_M_3
# R_sin_demanda_ABISINIA_7_H_1
# R_sin_demanda_ABISINIA_7_H_2
# R_sin_demanda_ABISINIA_7_H_3
# R_sin_demanda_ABISINIA_8_M_1
# R_sin_demanda_ABISINIA_8_M_2
# R_sin_demanda_ABISINIA_8_M_3
# R_sin_demanda_ABISINIA_8_H_1
# R_sin_demanda_ABISINIA_8_H_2
# R_sin_demanda_ABISINIA_8_H_3
# R_sin_demanda_ABISINIA_9_M_1
# R_sin_demanda_ABISINIA_9_M_2
# R_sin_demanda_ABISINIA_9_M_3
# R_sin_demanda_ABISINIA_9_H_1
# R_sin_demanda_ABISINIA_9_H_2
# R_sin_demanda_ABISINIA_9_H_3
# R_sin_demanda_ABISINIA_10_M_1
# R_sin_demanda_ABISINIA_10_M_2
# R_sin_demanda_ABISINIA_10_M_3
# R_sin_demanda_ABISINIA_10_H_1
# R_sin_demanda_ABISINIA_10_H_2
# R_sin_demanda_ABISINIA_10_H_3
# R_sin_demanda_CETEC ESCUELA VERDE_1_MX_1
# R_sin_demanda_CETEC ESCUELA VERDE_1_MX_2
# R_sin_demanda_CETEC ESCUELA VERDE_1_MX_3
# R_sin_demanda_CETEC ESCUELA VERDE_2_MX_1
# R_sin_demanda_CETEC ESCUELA VERDE_2_MX_2
# R_sin_demanda_CETEC ESCUELA VERDE_2_MX_3
# R_sin_demanda_EL ENCANTO_1_H_1
# R_sin_demanda_EL ENCANTO_1_H_2
# R_sin_demanda_EL ENCANTO_1_H_3
# R_sin_demanda_EL ENCANTO_1_H_4
# R_sin_demanda_EL ENCANTO_2_H_1
# R_sin_demanda_EL ENCANTO_2_H_2
# R_sin_demanda_EL ENCANTO_2_H_3
# R_sin_demanda_EL ENCANTO_2_H_4
# R_sin_demanda_EL ENCANTO_3_H_1
# R_sin_demanda_EL ENCANTO_3_H_2
# R_sin_demanda_EL ENCANTO_3_H_3
# R_sin_demanda_EL ENCANTO_3_H_4
# R_sin_demanda_EL ENCANTO_4_H_1
# R_sin_demanda_EL ENCANTO_4_H_2
# R_sin_demanda_EL ENCANTO_4_H_3
# R_sin_demanda_EL ENCANTO_4_H_4
# R_sin_demanda_EL ENCANTO_5_H_1
# R_sin_demanda_EL ENCANTO_5_H_2
# R_sin_demanda_EL ENCANTO_5_H_3
# R_sin_demanda_EL ENCANTO_5_H_4
# R_sin_demanda_EL ENCANTO_7_M_1
# R_sin_demanda_EL ENCANTO_7_M_2
# R_sin_demanda_EL ENCANTO_7_M_3
# R_sin_demanda_EL ENCANTO_7_M_4
# R_sin_demanda_EL ENCANTO_8_M_1
# R_sin_demanda_EL ENCANTO_8_M_2
# R_sin_demanda_EL ENCANTO_8_M_3
# R_sin_demanda_EL ENCANTO_8_M_4
# R_sin_demanda_EL ENCANTO_9_M_1
# R_sin_demanda_EL ENCANTO_9_M_2
# R_sin_demanda_EL ENCANTO_9_M_3
# R_sin_demanda_EL ENCANTO_9_M_4
# R_sin_demanda_EL ENCANTO_17_M_1
# R_sin_demanda_EL ENCANTO_17_M_2
# R_sin_demanda_EL ENCANTO_17_M_3
# R_sin_demanda_EL ENCANTO_17_M_4
# R_sin_demanda_EL ENCANTO_17_H_1
# R_sin_demanda_EL ENCANTO_17_H_2
# R_sin_demanda_EL ENCANTO_17_H_3
# R_sin_demanda_EL ENCANTO_17_H_4
# R_sin_demanda_EL ENCANTO_18_M_1
# R_sin_demanda_EL ENCANTO_18_M_2
# R_sin_demanda_EL ENCANTO_18_M_3
# R_sin_demanda_EL ENCANTO_18_M_4
# R_sin_demanda_EL ENCANTO_18_H_1
# R_sin_demanda_EL ENCANTO_18_H_2
# R_sin_demanda_EL ENCANTO_18_H_3
# R_sin_demanda_EL ENCANTO_18_H_4
# R_sin_demanda_LA AMANDA_1_M_1
# R_sin_demanda_LA AMANDA_1_M_2
# R_sin_demanda_LA AMANDA_1_M_3
# R_sin_demanda_LA AMANDA_1_M_4
# R_sin_demanda_LA AMANDA_2_M_1
# R_sin_demanda_LA AMANDA_2_M_2
# R_sin_demanda_LA AMANDA_2_M_3
# R_sin_demanda_LA AMANDA_2_M_4
# R_sin_demanda_LA AMANDA_2_M_5
# R_sin_demanda_LA AMANDA_3_H_1
# R_sin_demanda_LA AMANDA_3_H_2
# R_sin_demanda_LA AMANDA_3_H_3
# R_sin_demanda_LA AMANDA_3_H_4
# R_sin_demanda_LA AMANDA_4_H_1
# R_sin_demanda_LA AMANDA_4_H_2
# R_sin_demanda_LA AMANDA_4_H_3
# R_sin_demanda_LA AMANDA_4_H_4
# R_sin_demanda_LA AMANDA_4_H_5
# R_sin_demanda_LA AMANDA_5_M_1
# R_sin_demanda_LA AMANDA_5_M_2
# R_sin_demanda_LA AMANDA_5_M_3
# R_sin_demanda_LA AMANDA_5_M_4
# R_sin_demanda_LA AMANDA_5_M_5
# R_sin_demanda_LA AMANDA_6_H_1
# R_sin_demanda_LA AMANDA_6_H_2
# R_sin_demanda_LA AMANDA_6_H_3
# R_sin_demanda_LA AMANDA_6_H_4
# R_sin_demanda_LA AMANDA_6_H_5
# R_sin_demanda_LA AMANDA_7_H_1
# R_sin_demanda_LA AMANDA_7_H_2
# R_sin_demanda_LA AMANDA_7_H_3
# R_sin_demanda_LA AMANDA_7_H_4
# R_sin_demanda_LA AMANDA_7_H_5
# R_sin_demanda_LA CABAÑITA_1_H_1
# R_sin_demanda_LA CABAÑITA_1_H_2
# R_sin_demanda_LA CABAÑITA_1_H_3
# R_sin_demanda_LA CABAÑITA_1_H_4
# R_sin_demanda_LA CABAÑITA_1_H_5
# R_sin_demanda_LA CABAÑITA_1_H_6
# R_sin_demanda_LA CABAÑITA_2_H_1
# R_sin_demanda_LA CABAÑITA_2_H_2
# R_sin_demanda_LA CABAÑITA_2_H_3
# R_sin_demanda_LA CABAÑITA_2_H_4
# R_sin_demanda_LA CABAÑITA_2_H_5
# R_sin_demanda_LA CABAÑITA_2_H_6
# R_sin_demanda_LA CABAÑITA_3_H_1
# R_sin_demanda_LA CABAÑITA_3_H_2
# R_sin_demanda_LA CABAÑITA_3_H_3
# R_sin_demanda_LA CABAÑITA_3_H_4
# R_sin_demanda_LA CABAÑITA_3_H_5
# R_sin_demanda_LA CABAÑITA_3_H_6
# R_sin_demanda_LA CABAÑITA_4_M_1
# R_sin_demanda_LA CABAÑITA_4_M_2
# R_sin_demanda_LA CABAÑITA_4_M_3
# R_sin_demanda_LA CABAÑITA_4_M_4
# R_sin_demanda_LA CABAÑITA_4_M_5
# R_sin_demanda_LA CABAÑITA_4_M_6
# R_sin_demanda_LA CABAÑITA_5_MX_1
# R_sin_demanda_LA CABAÑITA_5_MX_2
# R_sin_demanda_LA CABAÑITA_5_MX_3
# R_sin_demanda_LA CABAÑITA_5_MX_4
# R_sin_demanda_LA CABAÑITA_5_MX_5
# R_sin_demanda_LA CABAÑITA_5_MX_6
# R_sin_demanda_LA CABAÑITA_6_M_1
# R_sin_demanda_LA CABAÑITA_6_M_2
# R_sin_demanda_LA CABAÑITA_6_M_3
# R_sin_demanda_LA CABAÑITA_6_M_4
# R_sin_demanda_LA CABAÑITA_6_M_5
# R_sin_demanda_LA CABAÑITA_6_M_6
# R_sin_demanda_LA CABAÑITA_7_M_1
# R_sin_demanda_LA CABAÑITA_7_M_2
# R_sin_demanda_LA CABAÑITA_7_M_3
# R_sin_demanda_LA CABAÑITA_7_M_4
# R_sin_demanda_LA CABAÑITA_7_M_5
# R_sin_demanda_LA CABAÑITA_7_M_6
# R_sin_demanda_BUENOS AIRES_1_H_1
# R_sin_demanda_BUENOS AIRES_1_H_2
# R_sin_demanda_BUENOS AIRES_1_H_3
# R_sin_demanda_BUENOS AIRES_1_H_4
# R_sin_demanda_BUENOS AIRES_1_H_5
# R_sin_demanda_BUENOS AIRES_1_H_6
# R_sin_demanda_BUENOS AIRES_2_H_1
# R_sin_demanda_BUENOS AIRES_2_H_2
# R_sin_demanda_BUENOS AIRES_2_H_3
# R_sin_demanda_BUENOS AIRES_2_H_4
# R_sin_demanda_BUENOS AIRES_2_H_5
# R_sin_demanda_BUENOS AIRES_2_H_6
# R_sin_demanda_BUENOS AIRES_3_M_1
# R_sin_demanda_BUENOS AIRES_3_M_2
# R_sin_demanda_BUENOS AIRES_3_M_3
# R_sin_demanda_BUENOS AIRES_3_M_4
# R_sin_demanda_BUENOS AIRES_3_M_5
# R_sin_demanda_BUENOS AIRES_3_M_6
# R_sin_demanda_BUENOS AIRES_6_M_1
# R_sin_demanda_BUENOS AIRES_6_M_2
# R_sin_demanda_BUENOS AIRES_6_M_3
# R_sin_demanda_BUENOS AIRES_6_M_4
# R_sin_demanda_BUENOS AIRES_6_M_5
# R_sin_demanda_BUENOS AIRES_6_M_6
# R_sin_demanda_BUENOS AIRES_7_H_1
# R_sin_demanda_BUENOS AIRES_7_H_2
# R_sin_demanda_BUENOS AIRES_7_H_3
# R_sin_demanda_BUENOS AIRES_7_H_4
# R_sin_demanda_BUENOS AIRES_7_H_5
# R_sin_demanda_BUENOS AIRES_7_H_6
# R_sin_demanda_EL ENCANTO_6_M_1
# R_sin_demanda_EL ENCANTO_6_M_2
# R_sin_demanda_EL ENCANTO_6_M_3
# R_sin_demanda_EL ENCANTO_6_M_4
# R_sin_demanda_EL ENCANTO_6_M_5
# R_sin_demanda_EL ENCANTO_6_M_6
# R_sin_demanda_EL ENCANTO_6_H_1
# R_sin_demanda_EL ENCANTO_6_H_2
# R_sin_demanda_EL ENCANTO_6_H_3
# R_sin_demanda_EL ENCANTO_6_H_4
# R_sin_demanda_EL ENCANTO_6_H_5
# R_sin_demanda_EL ENCANTO_6_H_6
# R_sin_demanda_EL ENCANTO_10_M_1
# R_sin_demanda_EL ENCANTO_10_M_2
# R_sin_demanda_EL ENCANTO_10_M_3
# R_sin_demanda_EL ENCANTO_10_M_4
# R_sin_demanda_EL ENCANTO_10_M_5
# R_sin_demanda_EL ENCANTO_10_M_6
# R_sin_demanda_EL ENCANTO_10_H_1
# R_sin_demanda_EL ENCANTO_10_H_2
# R_sin_demanda_EL ENCANTO_10_H_3
# R_sin_demanda_EL ENCANTO_10_H_4
# R_sin_demanda_EL ENCANTO_10_H_5
# R_sin_demanda_EL ENCANTO_10_H_6
# R_sin_demanda_EL ENCANTO_11_M_1
# R_sin_demanda_EL ENCANTO_11_M_2
# R_sin_demanda_EL ENCANTO_11_M_3
# R_sin_demanda_EL ENCANTO_11_M_4
# R_sin_demanda_EL ENCANTO_11_M_5
# R_sin_demanda_EL ENCANTO_11_M_6
# R_sin_demanda_EL ENCANTO_11_H_1
# R_sin_demanda_EL ENCANTO_11_H_2
# R_sin_demanda_EL ENCANTO_11_H_3
# R_sin_demanda_EL ENCANTO_11_H_4
# R_sin_demanda_EL ENCANTO_11_H_5
# R_sin_demanda_EL ENCANTO_11_H_6
# R_sin_demanda_EL ENCANTO_12_M_1
# R_sin_demanda_EL ENCANTO_12_M_2
# R_sin_demanda_EL ENCANTO_12_M_3
# R_sin_demanda_EL ENCANTO_12_M_4
# R_sin_demanda_EL ENCANTO_12_M_5
# R_sin_demanda_EL ENCANTO_12_M_6
# R_sin_demanda_EL ENCANTO_12_H_1
# R_sin_demanda_EL ENCANTO_12_H_2
# R_sin_demanda_EL ENCANTO_12_H_3
# R_sin_demanda_EL ENCANTO_12_H_4
# R_sin_demanda_EL ENCANTO_12_H_5
# R_sin_demanda_EL ENCANTO_12_H_6
# R_sin_demanda_EL ENCANTO_13_M_1
# R_sin_demanda_EL ENCANTO_13_M_2
# R_sin_demanda_EL ENCANTO_13_M_3
# R_sin_demanda_EL ENCANTO_13_M_4
# R_sin_demanda_EL ENCANTO_13_M_5
# R_sin_demanda_EL ENCANTO_13_M_6
# R_sin_demanda_EL ENCANTO_13_H_1
# R_sin_demanda_EL ENCANTO_13_H_2
# R_sin_demanda_EL ENCANTO_13_H_3
# R_sin_demanda_EL ENCANTO_13_H_4
# R_sin_demanda_EL ENCANTO_13_H_5
# R_sin_demanda_EL ENCANTO_13_H_6
# R_sin_demanda_EL ENCANTO_14_M_1
# R_sin_demanda_EL ENCANTO_14_M_2
# R_sin_demanda_EL ENCANTO_14_M_3
# R_sin_demanda_EL ENCANTO_14_M_4
# R_sin_demanda_EL ENCANTO_14_M_5
# R_sin_demanda_EL ENCANTO_14_M_6
# R_sin_demanda_EL ENCANTO_14_H_1
# R_sin_demanda_EL ENCANTO_14_H_2
# R_sin_demanda_EL ENCANTO_14_H_3
# R_sin_demanda_EL ENCANTO_14_H_4
# R_sin_demanda_EL ENCANTO_14_H_5
# R_sin_demanda_EL ENCANTO_14_H_6
# R_sin_demanda_EL ENCANTO_15_M_1
# R_sin_demanda_EL ENCANTO_15_M_2
# R_sin_demanda_EL ENCANTO_15_M_3
# R_sin_demanda_EL ENCANTO_15_M_4
# R_sin_demanda_EL ENCANTO_15_M_5
# R_sin_demanda_EL ENCANTO_15_M_6
# R_sin_demanda_EL ENCANTO_15_H_1
# R_sin_demanda_EL ENCANTO_15_H_2
# R_sin_demanda_EL ENCANTO_15_H_3
# R_sin_demanda_EL ENCANTO_15_H_4
# R_sin_demanda_EL ENCANTO_15_H_5
# R_sin_demanda_EL ENCANTO_15_H_6
# R_sin_demanda_EL ENCANTO_16_M_1
# R_sin_demanda_EL ENCANTO_16_M_2
# R_sin_demanda_EL ENCANTO_16_M_3
# R_sin_demanda_EL ENCANTO_16_M_4
# R_sin_demanda_EL ENCANTO_16_M_5
# R_sin_demanda_EL ENCANTO_16_M_6
# R_sin_demanda_EL ENCANTO_16_H_1
# R_sin_demanda_EL ENCANTO_16_H_2
# R_sin_demanda_EL ENCANTO_16_H_3
# R_sin_demanda_EL ENCANTO_16_H_4
# R_sin_demanda_EL ENCANTO_16_H_5
# R_sin_demanda_EL ENCANTO_16_H_6
# R_sin_demanda_BUENOS AIRES_4_M_1
# R_sin_demanda_BUENOS AIRES_4_M_2
# R_sin_demanda_BUENOS AIRES_4_M_3
# R_sin_demanda_BUENOS AIRES_4_M_4
# R_sin_demanda_BUENOS AIRES_4_M_5
# R_sin_demanda_BUENOS AIRES_4_M_6
# R_sin_demanda_BUENOS AIRES_4_M_8
# R_sin_demanda_BUENOS AIRES_5_H_1
# R_sin_demanda_BUENOS AIRES_5_H_2
# R_sin_demanda_BUENOS AIRES_5_H_3
# R_sin_demanda_BUENOS AIRES_5_H_4
# R_sin_demanda_BUENOS AIRES_5_H_5
# R_sin_demanda_BUENOS AIRES_5_H_6
# R_sin_demanda_BUENOS AIRES_5_H_8
# R_sin_demanda_CETEC SAN NICOLAS_1_MX_1
# R_sin_demanda_CETEC SAN NICOLAS_1_MX_2
# R_sin_demanda_CETEC SAN NICOLAS_1_MX_3
# R_sin_demanda_CETEC SAN NICOLAS_1_MX_4
# R_sin_demanda_CETEC SAN NICOLAS_1_MX_5
# R_sin_demanda_CETEC SAN NICOLAS_1_MX_6
# R_sin_demanda_CETEC SAN NICOLAS_1_MX_8
# R_sin_demanda_CETEC CRUCERO_1_MX_1
# R_sin_demanda_CETEC CRUCERO_1_MX_2
# R_sin_demanda_CETEC CRUCERO_1_MX_3
# R_sin_demanda_CETEC CRUCERO_1_MX_4
# R_sin_demanda_CETEC CRUCERO_1_MX_5
# R_sin_demanda_CETEC CRUCERO_1_MX_6
# R_sin_demanda_CETEC CRUCERO_1_MX_8
# R_sin_demanda_VILLA DEL LAGO_1_M_1
# R_sin_demanda_VILLA DEL LAGO_1_M_2
# R_sin_demanda_VILLA DEL LAGO_1_M_3
# R_sin_demanda_VILLA DEL LAGO_1_M_4
# R_sin_demanda_VILLA DEL LAGO_1_M_5
# R_sin_demanda_VILLA DEL LAGO_1_M_6
# R_sin_demanda_VILLA DEL LAGO_1_M_8
# R_sin_demanda_VILLA DEL LAGO_1_M_9
# R_sin_demanda_VILLA DEL LAGO_1_H_1
# R_sin_demanda_VILLA DEL LAGO_1_H_2
# R_sin_demanda_VILLA DEL LAGO_1_H_3
# R_sin_demanda_VILLA DEL LAGO_1_H_4
# R_sin_demanda_VILLA DEL LAGO_1_H_5
# R_sin_demanda_VILLA DEL LAGO_1_H_6
# R_sin_demanda_VILLA DEL LAGO_1_H_8
# R_sin_demanda_VILLA DEL LAGO_1_H_9
# R_sin_demanda_VILLA DEL LAGO_2_M_1
# R_sin_demanda_VILLA DEL LAGO_2_M_2
# R_sin_demanda_VILLA DEL LAGO_2_M_3
# R_sin_demanda_VILLA DEL LAGO_2_M_4
# R_sin_demanda_VILLA DEL LAGO_2_M_5
# R_sin_demanda_VILLA DEL LAGO_2_M_6
# R_sin_demanda_VILLA DEL LAGO_2_M_8
# R_sin_demanda_VILLA DEL LAGO_2_M_9
# R_sin_demanda_VILLA DEL LAGO_2_H_1
# R_sin_demanda_VILLA DEL LAGO_2_H_2
# R_sin_demanda_VILLA DEL LAGO_2_H_3
# R_sin_demanda_VILLA DEL LAGO_2_H_4
# R_sin_demanda_VILLA DEL LAGO_2_H_5
# R_sin_demanda_VILLA DEL LAGO_2_H_6
# R_sin_demanda_VILLA DEL LAGO_2_H_8
# R_sin_demanda_VILLA DEL LAGO_2_H_9
# R_sin_demanda_VILLA DEL LAGO_3_M_1
# R_sin_demanda_VILLA DEL LAGO_3_M_2
# R_sin_demanda_VILLA DEL LAGO_3_M_3
# R_sin_demanda_VILLA DEL LAGO_3_M_4
# R_sin_demanda_VILLA DEL LAGO_3_M_5
# R_sin_demanda_VILLA DEL LAGO_3_M_6
# R_sin_demanda_VILLA DEL LAGO_3_M_8
# R_sin_demanda_VILLA DEL LAGO_3_M_9
# R_sin_demanda_VILLA DEL LAGO_3_H_1
# R_sin_demanda_VILLA DEL LAGO_3_H_2
# R_sin_demanda_VILLA DEL LAGO_3_H_3
# R_sin_demanda_VILLA DEL LAGO_3_H_4
# R_sin_demanda_VILLA DEL LAGO_3_H_5
# R_sin_demanda_VILLA DEL LAGO_3_H_6
# R_sin_demanda_VILLA DEL LAGO_3_H_8
# R_sin_demanda_VILLA DEL LAGO_3_H_9
# R_sin_demanda_VILLA DEL LAGO_4_M_1
# R_sin_demanda_VILLA DEL LAGO_4_M_2
# R_sin_demanda_VILLA DEL LAGO_4_M_3
# R_sin_demanda_VILLA DEL LAGO_4_M_4
# R_sin_demanda_VILLA DEL LAGO_4_M_5
# R_sin_demanda_VILLA DEL LAGO_4_M_6
# R_sin_demanda_VILLA DEL LAGO_4_M_8
# R_sin_demanda_VILLA DEL LAGO_4_M_9
# R_sin_demanda_VILLA DEL LAGO_4_H_1
# R_sin_demanda_VILLA DEL LAGO_4_H_2
# R_sin_demanda_VILLA DEL LAGO_4_H_3
# R_sin_demanda_VILLA DEL LAGO_4_H_4
# R_sin_demanda_VILLA DEL LAGO_4_H_5
# R_sin_demanda_VILLA DEL LAGO_4_H_6
# R_sin_demanda_VILLA DEL LAGO_4_H_8
# R_sin_demanda_VILLA DEL LAGO_4_H_9
# R_sin_demanda_VILLA DEL LAGO_5_M_1
# R_sin_demanda_VILLA DEL LAGO_5_M_2
# R_sin_demanda_VILLA DEL LAGO_5_M_3
# R_sin_demanda_VILLA DEL LAGO_5_M_4
# R_sin_demanda_VILLA DEL LAGO_5_M_5
# R_sin_demanda_VILLA DEL LAGO_5_M_6
# R_sin_demanda_VILLA DEL LAGO_5_M_8
# R_sin_demanda_VILLA DEL LAGO_5_M_9
# R_sin_demanda_VILLA DEL LAGO_5_H_1
# R_sin_demanda_VILLA DEL LAGO_5_H_2
# R_sin_demanda_VILLA DEL LAGO_5_H_3
# R_sin_demanda_VILLA DEL LAGO_5_H_4
# R_sin_demanda_VILLA DEL LAGO_5_H_5
# R_sin_demanda_VILLA DEL LAGO_5_H_6
# R_sin_demanda_VILLA DEL LAGO_5_H_8
# R_sin_demanda_VILLA DEL LAGO_5_H_9
# R_sin_demanda_VILLA DEL LAGO_6_M_1
# R_sin_demanda_VILLA DEL LAGO_6_M_2
# R_sin_demanda_VILLA DEL LAGO_6_M_3
# R_sin_demanda_VILLA DEL LAGO_6_M_4
# R_sin_demanda_VILLA DEL LAGO_6_M_5
# R_sin_demanda_VILLA DEL LAGO_6_M_6
# R_sin_demanda_VILLA DEL LAGO_6_M_8
# R_sin_demanda_VILLA DEL LAGO_6_M_9
# R_sin_demanda_VILLA DEL LAGO_6_H_1
# R_sin_demanda_VILLA DEL LAGO_6_H_2
# R_sin_demanda_VILLA DEL LAGO_6_H_3
# R_sin_demanda_VILLA DEL LAGO_6_H_4
# R_sin_demanda_VILLA DEL LAGO_6_H_5
# R_sin_demanda_VILLA DEL LAGO_6_H_6
# R_sin_demanda_VILLA DEL LAGO_6_H_8
# R_sin_demanda_VILLA DEL LAGO_6_H_9
# R2_inferior_BLANCO_PEQUEÑO_1
# R2_superior_BLANCO_PEQUEÑO_1
# R2_inferior_BLANCO_PEQUEÑO_2
# R2_superior_BLANCO_PEQUEÑO_2
# R2_inferior_BLANCO_PEQUEÑO_3
# R2_superior_BLANCO_PEQUEÑO_3
# R2_inferior_BLANCO_PEQUEÑO_4
# R2_superior_BLANCO_PEQUEÑO_4
# R2_inferior_BLANCO_PEQUEÑO_5
# R2_superior_BLANCO_PEQUEÑO_5
# R2_inferior_BLANCO_PEQUEÑO_6
# R2_superior_BLANCO_PEQUEÑO_6
# R2_inferior_BLANCO_PEQUEÑO_7
# R2_superior_BLANCO_PEQUEÑO_7
# R2_inferior_BLANCO_PEQUEÑO_8
# R2_superior_BLANCO_PEQUEÑO_8
# R2_inferior_BLANCO_PEQUEÑO_9
# R2_superior_BLANCO_PEQUEÑO_9
# R2_inferior_BLANCO_PEQUEÑO_10
# R2_superior_BLANCO_PEQUEÑO_10
# R2_inferior_BLANCO_PEQUEÑO_11
# R2_superior_BLANCO_PEQUEÑO_11
# R2_inferior_BLANCO_PEQUEÑO_12
# R2_superior_BLANCO_PEQUEÑO_12
# R2_inferior_BLANCO_GRANDE_1
# R2_superior_BLANCO_GRANDE_1
# R2_inferior_BLANCO_GRANDE_2
# R2_superior_BLANCO_GRANDE_2
# R2_inferior_BLANCO_GRANDE_3
# R2_superior_BLANCO_GRANDE_3
# R2_inferior_BLANCO_GRANDE_4
# R2_superior_BLANCO_GRANDE_4
# R2_inferior_BLANCO_GRANDE_5
# R2_superior_BLANCO_GRANDE_5
# R2_inferior_BLANCO_GRANDE_6
# R2_superior_BLANCO_GRANDE_6
# R2_inferior_BLANCO_GRANDE_7
# R2_superior_BLANCO_GRANDE_7
# R2_inferior_BLANCO_GRANDE_8
# R2_superior_BLANCO_GRANDE_8
# R2_inferior_BLANCO_GRANDE_9
# R2_superior_BLANCO_GRANDE_9
# R2_inferior_BLANCO_GRANDE_10
# R2_superior_BLANCO_GRANDE_10
# R2_inferior_BLANCO_GRANDE_11
# R2_superior_BLANCO_GRANDE_11
# R2_inferior_BLANCO_GRANDE_12
# R2_superior_BLANCO_GRANDE_12
# R2_inferior_CAMPESINO_GRANDE_1
# R2_superior_CAMPESINO_GRANDE_1
# R2_inferior_CAMPESINO_GRANDE_2
# R2_superior_CAMPESINO_GRANDE_2
# R2_inferior_CAMPESINO_GRANDE_3
# R2_superior_CAMPESINO_GRANDE_3
# R2_inferior_CAMPESINO_GRANDE_4
# R2_superior_CAMPESINO_GRANDE_4
# R2_inferior_CAMPESINO_GRANDE_5
# R2_superior_CAMPESINO_GRANDE_5
# R2_inferior_CAMPESINO_GRANDE_6
# R2_superior_CAMPESINO_GRANDE_6
# R2_inferior_CAMPESINO_GRANDE_7
# R2_superior_CAMPESINO_GRANDE_7
# R2_inferior_CAMPESINO_GRANDE_8
# R2_superior_CAMPESINO_GRANDE_8
# R2_inferior_CAMPESINO_GRANDE_9
# R2_superior_CAMPESINO_GRANDE_9
# R2_inferior_CAMPESINO_GRANDE_10
# R2_superior_CAMPESINO_GRANDE_10
# R2_inferior_CAMPESINO_GRANDE_11
# R2_superior_CAMPESINO_GRANDE_11
# R2_inferior_CAMPESINO_GRANDE_12
# R2_superior_CAMPESINO_GRANDE_12
# R2sem_inferior_BLANCO_PEQUEÑO_sem1
# R2sem_superior_BLANCO_PEQUEÑO_sem1
# R2sem_inferior_BLANCO_PEQUEÑO_sem2
# R2sem_superior_BLANCO_PEQUEÑO_sem2
# R2sem_inferior_BLANCO_MEDIANO_sem1
# R2sem_superior_BLANCO_MEDIANO_sem1
# R2sem_inferior_BLANCO_MEDIANO_sem2
# R2sem_superior_BLANCO_MEDIANO_sem2
# desv_pos_BLANCO_PEQUEÑO_sem1
# desv_neg_BLANCO_PEQUEÑO_sem1
# desv_pos_BLANCO_PEQUEÑO_sem2
# desv_neg_BLANCO_PEQUEÑO_sem2
# desv_pos_BLANCO_MEDIANO_sem1
# desv_neg_BLANCO_MEDIANO_sem1
# desv_pos_BLANCO_MEDIANO_sem2
# desv_neg_BLANCO_MEDIANO_sem2
# R2_inferior_BLANCO_PEQUEÑO_1
# R2_superior_BLANCO_PEQUEÑO_1
# R2_inferior_BLANCO_PEQUEÑO_2
# R2_superior_BLANCO_PEQUEÑO_2
# R2_inferior_BLANCO_PEQUEÑO_3
# R2_superior_BLANCO_PEQUEÑO_3
# R2_inferior_BLANCO_PEQUEÑO_4
# R2_superior_BLANCO_PEQUEÑO_4
# R2_inferior_BLANCO_PEQUEÑO_5
# R2_superior_BLANCO_PEQUEÑO_5
# R2_inferior_BLANCO_PEQUEÑO_6
# R2_superior_BLANCO_PEQUEÑO_6
# R2_inferior_BLANCO_PEQUEÑO_7
# R2_superior_BLANCO_PEQUEÑO_7
# R2_inferior_BLANCO_PEQUEÑO_8
# R2_superior_BLANCO_PEQUEÑO_8
# R2_inferior_BLANCO_PEQUEÑO_9
# R2_superior_BLANCO_PEQUEÑO_9
# R2_inferior_BLANCO_PEQUEÑO_10
# R2_superior_BLANCO_PEQUEÑO_10
# R2_inferior_BLANCO_PEQUEÑO_11
# R2_superior_BLANCO_PEQUEÑO_11
# R2_inferior_BLANCO_PEQUEÑO_12
# R2_superior_BLANCO_PEQUEÑO_12
# R2_inferior_BLANCO_MEDIANO_1
# R2_superior_BLANCO_MEDIANO_1
# R2_inferior_BLANCO_MEDIANO_2
# R2_superior_BLANCO_MEDIANO_2
# R2_inferior_BLANCO_MEDIANO_3
# R2_superior_BLANCO_MEDIANO_3
# R2_inferior_BLANCO_MEDIANO_4
# R2_superior_BLANCO_MEDIANO_4
# R2_inferior_BLANCO_MEDIANO_5
# R2_superior_BLANCO_MEDIANO_5
# R2_inferior_BLANCO_MEDIANO_6
# R2_superior_BLANCO_MEDIANO_6
# R2_inferior_BLANCO_MEDIANO_7
# R2_superior_BLANCO_MEDIANO_7
# R2_inferior_BLANCO_MEDIANO_8
# R2_superior_BLANCO_MEDIANO_8
# R2_inferior_BLANCO_MEDIANO_9
# R2_superior_BLANCO_MEDIANO_9
# R2_inferior_BLANCO_MEDIANO_10
# R2_superior_BLANCO_MEDIANO_10
# R2_inferior_BLANCO_MEDIANO_11
# R2_superior_BLANCO_MEDIANO_11
# R2_inferior_BLANCO_MEDIANO_12
# R2_superior_BLANCO_MEDIANO_12
# R2sem_inferior_BLANCO_PEQUEÑO_sem1
# R2sem_superior_BLANCO_PEQUEÑO_sem1
# R2sem_inferior_BLANCO_PEQUEÑO_sem2
# R2sem_superior_BLANCO_PEQUEÑO_sem2
# R2sem_inferior_BLANCO_MEDIANO_sem1
# R2sem_superior_BLANCO_MEDIANO_sem1
# R2sem_inferior_BLANCO_MEDIANO_sem2
# R2sem_superior_BLANCO_MEDIANO_sem2
# desv_pos_BLANCO_PEQUEÑO_sem1
# desv_neg_BLANCO_PEQUEÑO_sem1
# desv_pos_BLANCO_PEQUEÑO_sem2
# desv_neg_BLANCO_PEQUEÑO_sem2
# desv_pos_BLANCO_MEDIANO_sem1
# desv_neg_BLANCO_MEDIANO_sem1
# desv_pos_BLANCO_MEDIANO_sem2
# desv_neg_BLANCO_MEDIANO_sem2
